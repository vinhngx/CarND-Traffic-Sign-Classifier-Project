# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = 'data/train.p'
validation_file= 'data/valid.p'
testing_file = 'data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
import numpy as np

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train.shape[1:3]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of validation examples =", n_validation)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of validation examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
#plot class distribution across different sets
plt.figure;
plt.subplot(1,3,1)
plt.hist(y_train, 43);
plt.title('Train')
plt.subplot(1,3,2)
plt.hist(y_valid, 43);
plt.title('Validation')
plt.subplot(1,3,3)
plt.hist(y_test, 43);
plt.title('Test')
plt.suptitle('Class distribution');

# %%
#plot a random selection of images belonging to a class
#read label description
import pandas as pd
label_desc=pd.read_csv('signnames.csv', sep=',')

for class_id in range(43):
    items = np.argwhere(y_train==class_id)
    np.random.shuffle(items)
    plt.figure(figsize=(20,4))    
    for i in range(10):
        plt.subplot(1,10,i+1)
        plt.imshow(X_train[items[i][0],:])
        plt.axis('off')
    plt.suptitle('Class %d: %s'%(class_id, label_desc.ix[class_id][1]))
    plt.show()
# Out:
# /home/xnguyen/.local/lib/python3.5/site-packages/ipykernel_launcher.py:14: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.
X_train_normalized = (X_train - 128.)/128
X_test_normalized = (X_test - 128.)/128
X_valid_normalized = (X_valid - 128.)/128

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
from tensorflow.contrib.layers import flatten
import tensorflow as tf

def LeNet(x, prob):  
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 32x32x16.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 3, 16), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(16))
    x       = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='SAME') + conv1_b
    x       = tf.nn.relu(x)
    
    L2_regularizer = tf.nn.l2_loss(conv1_W) + tf.nn.l2_loss(conv1_b)
    
    # SOLUTION: Layer 12: Convolutional. Input = 32x32x16. Output = 32x32x16.
    conv12_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 16), mean = mu, stddev = sigma))
    conv12_b = tf.Variable(tf.zeros(16))
    x        = tf.nn.conv2d(x, conv12_W, strides=[1, 1, 1, 1], padding='SAME') + conv12_b
    x        = tf.nn.relu(x)
    
    L2_regularizer += tf.nn.l2_loss(conv12_W) + tf.nn.l2_loss(conv12_b)
    
    # SOLUTION: Pooling. Input = 32x32x16. Output = 16x16x16.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 16x16x32.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 32), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(32))
    x       = tf.nn.conv2d(x, conv2_W, strides=[1, 1, 1, 1], padding='SAME') + conv2_b
    x       = tf.nn.relu(x)
    #x       = tf.nn.dropout(x, keep_prob=0.5)
    
    L2_regularizer += tf.nn.l2_loss(conv2_W) + tf.nn.l2_loss(conv2_b)
    
    # SOLUTION: Layer 22: Convolutional. Input = 16x16x32. Output = 16x16x64.
    conv22_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 32, 64), mean = mu, stddev = sigma))
    conv22_b = tf.Variable(tf.zeros(64))
    x        = tf.nn.conv2d(x, conv22_W, strides=[1, 1, 1, 1], padding='SAME') + conv22_b
    x        = tf.nn.relu(x)
    #x        = tf.nn.dropout(x, keep_prob=0.5)
    
    L2_regularizer += tf.nn.l2_loss(conv22_W) + tf.nn.l2_loss(conv22_b)
    
    
    # SOLUTION: Pooling. Input = 16x16x64. Output = 8x8x64.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    # Global average pooling layer
    x = tf.reduce_mean(x, [1,2])
    
    # SOLUTION: Flatten. Input = 64. Output = 64.
    x    = flatten(x)
    x    = tf.nn.dropout(x, keep_prob=prob)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 64. Output = 43.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(64, 43), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(43))
    x   = tf.matmul(x, fc1_W) + fc1_b
    
    L2_regularizer += tf.nn.l2_loss(fc1_W) + tf.nn.l2_loss(fc1_b)
    
    return x, L2_regularizer
# Out:
# /home/xnguyen/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 3))
y = tf.placeholder(tf.int32, (None))
prob = tf.placeholder(tf.float32, name='keep_prob')

one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits, L2_regularizer = LeNet(x, prob)
L2_REGULARIZER = 1e-4

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits) + L2_REGULARIZER*L2_regularizer
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy, loss = sess.run([accuracy_operation, loss_operation], feed_dict={x: batch_x, y: batch_y, prob: 1})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples, loss
# Out:
# WARNING:tensorflow:From <ipython-input-8-77de9617e30e>:12: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

from sklearn.utils import shuffle

EPOCHS=500
BATCH_SIZE = 1024

# %%
acc_arr = []
loss_arr = []
val_acc_arr = []
val_loss_arr = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train_normalized)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train_normalized, y_train = shuffle(X_train_normalized, y_train)

        ep_acc_arr = []
        ep_loss_arr = []        
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train_normalized[offset:end], y_train[offset:end]
            _, loss, acc = sess.run([training_operation, loss_operation, accuracy_operation], 
                                    feed_dict={x: batch_x, y: batch_y, prob: 0.5})
            ep_loss_arr.append(loss)
            ep_acc_arr.append(acc)
        
        acc_arr.append(np.mean(ep_acc_arr))
        loss_arr.append(np.mean(ep_loss_arr))
        validation_accuracy, validation_loss = evaluate(X_valid_normalized, y_valid)
        val_acc_arr.append(validation_accuracy)
        val_loss_arr.append(validation_loss)
        
        print("EPOCH {} Loss = {:.3f} Validation loss: {:.3f} Train Accuracy = {:.3f} Validation Accuracy = {:.3f}".format(i+1,
                                                                                                                             loss_arr[-1], 
                                                                                                                             val_loss_arr[-1], 
                                                                                                                             acc_arr[-1], 
                                                                                                                             validation_accuracy))
        
        if i%10==0:
            saver.save(sess, './lenetmodel/lenet')
    saver.save(sess, './lenetmodel/lenet')
    print("Final model saved")
    
plt.plot(loss_arr)
plt.plot(acc_arr)
plt.plot(val_loss_arr)
plt.plot(val_acc_arr)
plt.legend(['Loss', 'Train Accuracy', 'Validation Loss', 'Validation Accuracy'])
# Out:
# Training...
#
# EPOCH 1 Loss = 3.597 Validation loss: 3.140 Train Accuracy = 0.057 Validation Accuracy = 0.084
# EPOCH 2 Loss = 3.378 Validation loss: 2.958 Train Accuracy = 0.100 Validation Accuracy = 0.111
# EPOCH 3 Loss = 3.232 Validation loss: 2.876 Train Accuracy = 0.117 Validation Accuracy = 0.131
# EPOCH 4 Loss = 3.154 Validation loss: 2.891 Train Accuracy = 0.127 Validation Accuracy = 0.131
# EPOCH 5 Loss = 3.101 Validation loss: 2.822 Train Accuracy = 0.136 Validation Accuracy = 0.123
# EPOCH 6 Loss = 3.060 Validation loss: 2.758 Train Accuracy = 0.142 Validation Accuracy = 0.119
# EPOCH 7 Loss = 3.023 Validation loss: 2.810 Train Accuracy = 0.148 Validation Accuracy = 0.120
# EPOCH 8 Loss = 2.986 Validation loss: 2.745 Train Accuracy = 0.158 Validation Accuracy = 0.124
# EPOCH 9 Loss = 2.947 Validation loss: 2.779 Train Accuracy = 0.169 Validation Accuracy = 0.139
# EPOCH 10 Loss = 2.891 Validation loss: 2.742 Train Accuracy = 0.184 Validation Accuracy = 0.168
# EPOCH 11 Loss = 2.847 Validation loss: 2.673 Train Accuracy = 0.195 Validation Accuracy = 0.172
# EPOCH 12 Loss = 2.804 Validation loss: 2.612 Train Accuracy = 0.203 Validation Accuracy = 0.171
# EPOCH 13 Loss = 2.756 Validation loss: 2.484 Train Accuracy = 0.211 Validation Accuracy = 0.174
# EPOCH 14 Loss = 2.711 Validation loss: 2.574 Train Accuracy = 0.221 Validation Accuracy = 0.196
# EPOCH 15 Loss = 2.683 Validation loss: 2.531 Train Accuracy = 0.226 Validation Accuracy = 0.201
# EPOCH 16 Loss = 2.631 Validation loss: 2.539 Train Accuracy = 0.239 Validation Accuracy = 0.202
# EPOCH 17 Loss = 2.594 Validation loss: 2.373 Train Accuracy = 0.247 Validation Accuracy = 0.223
# EPOCH 18 Loss = 2.554 Validation loss: 2.388 Train Accuracy = 0.255 Validation Accuracy = 0.228
# EPOCH 19 Loss = 2.512 Validation loss: 2.315 Train Accuracy = 0.264 Validation Accuracy = 0.257
# EPOCH 20 Loss = 2.474 Validation loss: 2.318 Train Accuracy = 0.272 Validation Accuracy = 0.251
# EPOCH 21 Loss = 2.427 Validation loss: 2.166 Train Accuracy = 0.282 Validation Accuracy = 0.255
# EPOCH 22 Loss = 2.388 Validation loss: 2.320 Train Accuracy = 0.293 Validation Accuracy = 0.263
# EPOCH 23 Loss = 2.334 Validation loss: 2.094 Train Accuracy = 0.305 Validation Accuracy = 0.309
# EPOCH 24 Loss = 2.292 Validation loss: 2.112 Train Accuracy = 0.316 Validation Accuracy = 0.313
# EPOCH 25 Loss = 2.252 Validation loss: 2.035 Train Accuracy = 0.324 Validation Accuracy = 0.327
# EPOCH 26 Loss = 2.222 Validation loss: 2.162 Train Accuracy = 0.333 Validation Accuracy = 0.331
# EPOCH 27 Loss = 2.174 Validation loss: 1.988 Train Accuracy = 0.346 Validation Accuracy = 0.345
# EPOCH 28 Loss = 2.138 Validation loss: 2.004 Train Accuracy = 0.352 Validation Accuracy = 0.359
# EPOCH 29 Loss = 2.112 Validation loss: 1.989 Train Accuracy = 0.356 Validation Accuracy = 0.354
# EPOCH 30 Loss = 2.067 Validation loss: 1.961 Train Accuracy = 0.366 Validation Accuracy = 0.373
# EPOCH 31 Loss = 2.039 Validation loss: 2.067 Train Accuracy = 0.375 Validation Accuracy = 0.378
# EPOCH 32 Loss = 2.006 Validation loss: 2.023 Train Accuracy = 0.384 Validation Accuracy = 0.395
# EPOCH 33 Loss = 1.987 Validation loss: 1.912 Train Accuracy = 0.389 Validation Accuracy = 0.399
# EPOCH 34 Loss = 1.950 Validation loss: 1.945 Train Accuracy = 0.403 Validation Accuracy = 0.409
# EPOCH 35 Loss = 1.923 Validation loss: 1.858 Train Accuracy = 0.409 Validation Accuracy = 0.411
# EPOCH 36 Loss = 1.896 Validation loss: 1.958 Train Accuracy = 0.413 Validation Accuracy = 0.423
# EPOCH 37 Loss = 1.852 Validation loss: 1.855 Train Accuracy = 0.427 Validation Accuracy = 0.423
# EPOCH 38 Loss = 1.837 Validation loss: 1.933 Train Accuracy = 0.430 Validation Accuracy = 0.432
# EPOCH 39 Loss = 1.804 Validation loss: 1.871 Train Accuracy = 0.441 Validation Accuracy = 0.439
# EPOCH 40 Loss = 1.785 Validation loss: 1.811 Train Accuracy = 0.449 Validation Accuracy = 0.452
# EPOCH 41 Loss = 1.741 Validation loss: 1.793 Train Accuracy = 0.461 Validation Accuracy = 0.468
# EPOCH 42 Loss = 1.730 Validation loss: 1.744 Train Accuracy = 0.462 Validation Accuracy = 0.469
# EPOCH 43 Loss = 1.691 Validation loss: 1.880 Train Accuracy = 0.472 Validation Accuracy = 0.476
# EPOCH 44 Loss = 1.673 Validation loss: 1.858 Train Accuracy = 0.479 Validation Accuracy = 0.462
# EPOCH 45 Loss = 1.654 Validation loss: 1.783 Train Accuracy = 0.482 Validation Accuracy = 0.487
# EPOCH 46 Loss = 1.614 Validation loss: 1.788 Train Accuracy = 0.496 Validation Accuracy = 0.490
# EPOCH 47 Loss = 1.591 Validation loss: 1.796 Train Accuracy = 0.501 Validation Accuracy = 0.507
# EPOCH 48 Loss = 1.566 Validation loss: 1.662 Train Accuracy = 0.510 Validation Accuracy = 0.519
# EPOCH 49 Loss = 1.543 Validation loss: 1.722 Train Accuracy = 0.516 Validation Accuracy = 0.528
# EPOCH 50 Loss = 1.515 Validation loss: 1.578 Train Accuracy = 0.525 Validation Accuracy = 0.539
# EPOCH 51 Loss = 1.497 Validation loss: 1.638 Train Accuracy = 0.531 Validation Accuracy = 0.547
# EPOCH 52 Loss = 1.484 Validation loss: 1.690 Train Accuracy = 0.534 Validation Accuracy = 0.554
# EPOCH 53 Loss = 1.453 Validation loss: 1.653 Train Accuracy = 0.548 Validation Accuracy = 0.573
# EPOCH 54 Loss = 1.426 Validation loss: 1.550 Train Accuracy = 0.555 Validation Accuracy = 0.575
# EPOCH 55 Loss = 1.396 Validation loss: 1.499 Train Accuracy = 0.565 Validation Accuracy = 0.584
# EPOCH 56 Loss = 1.390 Validation loss: 1.546 Train Accuracy = 0.567 Validation Accuracy = 0.592
# EPOCH 57 Loss = 1.345 Validation loss: 1.428 Train Accuracy = 0.582 Validation Accuracy = 0.603
# EPOCH 58 Loss = 1.330 Validation loss: 1.457 Train Accuracy = 0.588 Validation Accuracy = 0.616
# EPOCH 59 Loss = 1.305 Validation loss: 1.320 Train Accuracy = 0.594 Validation Accuracy = 0.615
# EPOCH 60 Loss = 1.291 Validation loss: 1.430 Train Accuracy = 0.601 Validation Accuracy = 0.611
# EPOCH 61 Loss = 1.266 Validation loss: 1.382 Train Accuracy = 0.606 Validation Accuracy = 0.629
# EPOCH 62 Loss = 1.240 Validation loss: 1.356 Train Accuracy = 0.618 Validation Accuracy = 0.637
# EPOCH 63 Loss = 1.227 Validation loss: 1.343 Train Accuracy = 0.623 Validation Accuracy = 0.642
# EPOCH 64 Loss = 1.206 Validation loss: 1.346 Train Accuracy = 0.626 Validation Accuracy = 0.632
# EPOCH 65 Loss = 1.183 Validation loss: 1.335 Train Accuracy = 0.639 Validation Accuracy = 0.654
# EPOCH 66 Loss = 1.173 Validation loss: 1.225 Train Accuracy = 0.642 Validation Accuracy = 0.651
# EPOCH 67 Loss = 1.150 Validation loss: 1.359 Train Accuracy = 0.649 Validation Accuracy = 0.662
# EPOCH 68 Loss = 1.134 Validation loss: 1.255 Train Accuracy = 0.654 Validation Accuracy = 0.663
# EPOCH 69 Loss = 1.108 Validation loss: 1.244 Train Accuracy = 0.660 Validation Accuracy = 0.670
# EPOCH 70 Loss = 1.080 Validation loss: 1.253 Train Accuracy = 0.670 Validation Accuracy = 0.671
# EPOCH 71 Loss = 1.069 Validation loss: 1.245 Train Accuracy = 0.674 Validation Accuracy = 0.676
# EPOCH 72 Loss = 1.053 Validation loss: 1.274 Train Accuracy = 0.679 Validation Accuracy = 0.687
# EPOCH 73 Loss = 1.039 Validation loss: 1.205 Train Accuracy = 0.683 Validation Accuracy = 0.694
# EPOCH 74 Loss = 1.028 Validation loss: 1.100 Train Accuracy = 0.691 Validation Accuracy = 0.703
# EPOCH 75 Loss = 1.007 Validation loss: 1.110 Train Accuracy = 0.698 Validation Accuracy = 0.704
# EPOCH 76 Loss = 0.998 Validation loss: 1.214 Train Accuracy = 0.701 Validation Accuracy = 0.707
# EPOCH 77 Loss = 0.977 Validation loss: 1.164 Train Accuracy = 0.706 Validation Accuracy = 0.717
# EPOCH 78 Loss = 0.959 Validation loss: 1.096 Train Accuracy = 0.713 Validation Accuracy = 0.725
# EPOCH 79 Loss = 0.949 Validation loss: 1.040 Train Accuracy = 0.718 Validation Accuracy = 0.717
# EPOCH 80 Loss = 0.941 Validation loss: 1.102 Train Accuracy = 0.720 Validation Accuracy = 0.748
# EPOCH 81 Loss = 0.922 Validation loss: 1.051 Train Accuracy = 0.729 Validation Accuracy = 0.733
# EPOCH 82 Loss = 0.910 Validation loss: 0.962 Train Accuracy = 0.734 Validation Accuracy = 0.751
# EPOCH 83 Loss = 0.891 Validation loss: 0.920 Train Accuracy = 0.737 Validation Accuracy = 0.751
# EPOCH 84 Loss = 0.879 Validation loss: 1.041 Train Accuracy = 0.742 Validation Accuracy = 0.768
# EPOCH 85 Loss = 0.880 Validation loss: 0.984 Train Accuracy = 0.744 Validation Accuracy = 0.782
# EPOCH 86 Loss = 0.854 Validation loss: 0.855 Train Accuracy = 0.750 Validation Accuracy = 0.771
# EPOCH 87 Loss = 0.842 Validation loss: 0.866 Train Accuracy = 0.755 Validation Accuracy = 0.779
# EPOCH 88 Loss = 0.838 Validation loss: 0.865 Train Accuracy = 0.758 Validation Accuracy = 0.778
# EPOCH 89 Loss = 0.823 Validation loss: 0.817 Train Accuracy = 0.761 Validation Accuracy = 0.794
# EPOCH 90 Loss = 0.815 Validation loss: 0.849 Train Accuracy = 0.765 Validation Accuracy = 0.789
# EPOCH 91 Loss = 0.807 Validation loss: 0.865 Train Accuracy = 0.767 Validation Accuracy = 0.800
# EPOCH 92 Loss = 0.800 Validation loss: 0.884 Train Accuracy = 0.770 Validation Accuracy = 0.800
# EPOCH 93 Loss = 0.782 Validation loss: 0.731 Train Accuracy = 0.776 Validation Accuracy = 0.795
# EPOCH 94 Loss = 0.780 Validation loss: 0.751 Train Accuracy = 0.778 Validation Accuracy = 0.805
# EPOCH 95 Loss = 0.765 Validation loss: 0.766 Train Accuracy = 0.781 Validation Accuracy = 0.815
# EPOCH 96 Loss = 0.759 Validation loss: 0.668 Train Accuracy = 0.786 Validation Accuracy = 0.813
# EPOCH 97 Loss = 0.750 Validation loss: 0.744 Train Accuracy = 0.789 Validation Accuracy = 0.821
# EPOCH 98 Loss = 0.738 Validation loss: 0.672 Train Accuracy = 0.790 Validation Accuracy = 0.822
# EPOCH 99 Loss = 0.733 Validation loss: 0.678 Train Accuracy = 0.792 Validation Accuracy = 0.826
# EPOCH 100 Loss = 0.715 Validation loss: 0.689 Train Accuracy = 0.798 Validation Accuracy = 0.827
# EPOCH 101 Loss = 0.716 Validation loss: 0.663 Train Accuracy = 0.798 Validation Accuracy = 0.829
# EPOCH 102 Loss = 0.705 Validation loss: 0.660 Train Accuracy = 0.803 Validation Accuracy = 0.830
# EPOCH 103 Loss = 0.702 Validation loss: 0.651 Train Accuracy = 0.803 Validation Accuracy = 0.838
# EPOCH 104 Loss = 0.687 Validation loss: 0.518 Train Accuracy = 0.811 Validation Accuracy = 0.849
# EPOCH 105 Loss = 0.688 Validation loss: 0.584 Train Accuracy = 0.809 Validation Accuracy = 0.846
# EPOCH 106 Loss = 0.673 Validation loss: 0.586 Train Accuracy = 0.816 Validation Accuracy = 0.844
# EPOCH 107 Loss = 0.669 Validation loss: 0.596 Train Accuracy = 0.815 Validation Accuracy = 0.846
# EPOCH 108 Loss = 0.664 Validation loss: 0.569 Train Accuracy = 0.815 Validation Accuracy = 0.853
# EPOCH 109 Loss = 0.658 Validation loss: 0.589 Train Accuracy = 0.822 Validation Accuracy = 0.846
# EPOCH 110 Loss = 0.648 Validation loss: 0.520 Train Accuracy = 0.824 Validation Accuracy = 0.852
# EPOCH 111 Loss = 0.643 Validation loss: 0.559 Train Accuracy = 0.826 Validation Accuracy = 0.851
# EPOCH 112 Loss = 0.635 Validation loss: 0.588 Train Accuracy = 0.827 Validation Accuracy = 0.851
# EPOCH 113 Loss = 0.633 Validation loss: 0.525 Train Accuracy = 0.829 Validation Accuracy = 0.867
# EPOCH 114 Loss = 0.628 Validation loss: 0.593 Train Accuracy = 0.831 Validation Accuracy = 0.861
# EPOCH 115 Loss = 0.624 Validation loss: 0.550 Train Accuracy = 0.833 Validation Accuracy = 0.855
# EPOCH 116 Loss = 0.623 Validation loss: 0.433 Train Accuracy = 0.830 Validation Accuracy = 0.870
# EPOCH 117 Loss = 0.603 Validation loss: 0.460 Train Accuracy = 0.841 Validation Accuracy = 0.869
# EPOCH 118 Loss = 0.605 Validation loss: 0.452 Train Accuracy = 0.838 Validation Accuracy = 0.874
# EPOCH 119 Loss = 0.591 Validation loss: 0.473 Train Accuracy = 0.844 Validation Accuracy = 0.874
# EPOCH 120 Loss = 0.583 Validation loss: 0.483 Train Accuracy = 0.844 Validation Accuracy = 0.874
# EPOCH 121 Loss = 0.580 Validation loss: 0.454 Train Accuracy = 0.847 Validation Accuracy = 0.878
# EPOCH 122 Loss = 0.577 Validation loss: 0.413 Train Accuracy = 0.847 Validation Accuracy = 0.879
# EPOCH 123 Loss = 0.572 Validation loss: 0.462 Train Accuracy = 0.850 Validation Accuracy = 0.878
# EPOCH 124 Loss = 0.580 Validation loss: 0.507 Train Accuracy = 0.847 Validation Accuracy = 0.872
# EPOCH 125 Loss = 0.563 Validation loss: 0.432 Train Accuracy = 0.853 Validation Accuracy = 0.878
# EPOCH 126 Loss = 0.553 Validation loss: 0.432 Train Accuracy = 0.856 Validation Accuracy = 0.888
# EPOCH 127 Loss = 0.547 Validation loss: 0.488 Train Accuracy = 0.857 Validation Accuracy = 0.886
# EPOCH 128 Loss = 0.544 Validation loss: 0.419 Train Accuracy = 0.858 Validation Accuracy = 0.888
# EPOCH 129 Loss = 0.536 Validation loss: 0.414 Train Accuracy = 0.861 Validation Accuracy = 0.890
# EPOCH 130 Loss = 0.537 Validation loss: 0.364 Train Accuracy = 0.861 Validation Accuracy = 0.888
# EPOCH 131 Loss = 0.528 Validation loss: 0.452 Train Accuracy = 0.863 Validation Accuracy = 0.897
# EPOCH 132 Loss = 0.527 Validation loss: 0.435 Train Accuracy = 0.866 Validation Accuracy = 0.895
# EPOCH 133 Loss = 0.527 Validation loss: 0.422 Train Accuracy = 0.864 Validation Accuracy = 0.901
# EPOCH 134 Loss = 0.529 Validation loss: 0.396 Train Accuracy = 0.864 Validation Accuracy = 0.899
# EPOCH 135 Loss = 0.515 Validation loss: 0.366 Train Accuracy = 0.869 Validation Accuracy = 0.895
# EPOCH 136 Loss = 0.514 Validation loss: 0.379 Train Accuracy = 0.870 Validation Accuracy = 0.902
# EPOCH 137 Loss = 0.505 Validation loss: 0.429 Train Accuracy = 0.871 Validation Accuracy = 0.901
# EPOCH 138 Loss = 0.508 Validation loss: 0.421 Train Accuracy = 0.873 Validation Accuracy = 0.905
# EPOCH 139 Loss = 0.502 Validation loss: 0.392 Train Accuracy = 0.874 Validation Accuracy = 0.910
# EPOCH 140 Loss = 0.499 Validation loss: 0.378 Train Accuracy = 0.875 Validation Accuracy = 0.904
# EPOCH 141 Loss = 0.497 Validation loss: 0.420 Train Accuracy = 0.877 Validation Accuracy = 0.903
# EPOCH 142 Loss = 0.492 Validation loss: 0.421 Train Accuracy = 0.876 Validation Accuracy = 0.903
# EPOCH 143 Loss = 0.494 Validation loss: 0.372 Train Accuracy = 0.877 Validation Accuracy = 0.908
# EPOCH 144 Loss = 0.487 Validation loss: 0.337 Train Accuracy = 0.878 Validation Accuracy = 0.910
# EPOCH 145 Loss = 0.482 Validation loss: 0.345 Train Accuracy = 0.881 Validation Accuracy = 0.915
# EPOCH 146 Loss = 0.482 Validation loss: 0.383 Train Accuracy = 0.880 Validation Accuracy = 0.911
# EPOCH 147 Loss = 0.473 Validation loss: 0.300 Train Accuracy = 0.883 Validation Accuracy = 0.909
# EPOCH 148 Loss = 0.477 Validation loss: 0.376 Train Accuracy = 0.883 Validation Accuracy = 0.910
# EPOCH 149 Loss = 0.469 Validation loss: 0.345 Train Accuracy = 0.884 Validation Accuracy = 0.920
# EPOCH 150 Loss = 0.462 Validation loss: 0.352 Train Accuracy = 0.890 Validation Accuracy = 0.916
# EPOCH 151 Loss = 0.458 Validation loss: 0.342 Train Accuracy = 0.889 Validation Accuracy = 0.919
# EPOCH 152 Loss = 0.457 Validation loss: 0.342 Train Accuracy = 0.888 Validation Accuracy = 0.913
# EPOCH 153 Loss = 0.458 Validation loss: 0.319 Train Accuracy = 0.891 Validation Accuracy = 0.915
# EPOCH 154 Loss = 0.455 Validation loss: 0.318 Train Accuracy = 0.890 Validation Accuracy = 0.918
# EPOCH 155 Loss = 0.455 Validation loss: 0.342 Train Accuracy = 0.889 Validation Accuracy = 0.907
# EPOCH 156 Loss = 0.446 Validation loss: 0.327 Train Accuracy = 0.895 Validation Accuracy = 0.921
# EPOCH 157 Loss = 0.444 Validation loss: 0.319 Train Accuracy = 0.893 Validation Accuracy = 0.922
# EPOCH 158 Loss = 0.437 Validation loss: 0.349 Train Accuracy = 0.896 Validation Accuracy = 0.925
# EPOCH 159 Loss = 0.429 Validation loss: 0.301 Train Accuracy = 0.899 Validation Accuracy = 0.917
# EPOCH 160 Loss = 0.435 Validation loss: 0.307 Train Accuracy = 0.898 Validation Accuracy = 0.922
# EPOCH 161 Loss = 0.424 Validation loss: 0.289 Train Accuracy = 0.899 Validation Accuracy = 0.930
# EPOCH 162 Loss = 0.431 Validation loss: 0.344 Train Accuracy = 0.899 Validation Accuracy = 0.922
# EPOCH 163 Loss = 0.419 Validation loss: 0.339 Train Accuracy = 0.902 Validation Accuracy = 0.924
# EPOCH 164 Loss = 0.423 Validation loss: 0.313 Train Accuracy = 0.903 Validation Accuracy = 0.930
# EPOCH 165 Loss = 0.417 Validation loss: 0.289 Train Accuracy = 0.905 Validation Accuracy = 0.925
# EPOCH 166 Loss = 0.422 Validation loss: 0.310 Train Accuracy = 0.901 Validation Accuracy = 0.932
# EPOCH 167 Loss = 0.415 Validation loss: 0.368 Train Accuracy = 0.904 Validation Accuracy = 0.927
# EPOCH 168 Loss = 0.407 Validation loss: 0.299 Train Accuracy = 0.907 Validation Accuracy = 0.930
# EPOCH 169 Loss = 0.403 Validation loss: 0.289 Train Accuracy = 0.907 Validation Accuracy = 0.932
# EPOCH 170 Loss = 0.403 Validation loss: 0.278 Train Accuracy = 0.909 Validation Accuracy = 0.933
# EPOCH 171 Loss = 0.404 Validation loss: 0.276 Train Accuracy = 0.908 Validation Accuracy = 0.934
# EPOCH 172 Loss = 0.394 Validation loss: 0.315 Train Accuracy = 0.910 Validation Accuracy = 0.925
# EPOCH 173 Loss = 0.392 Validation loss: 0.266 Train Accuracy = 0.912 Validation Accuracy = 0.936
# EPOCH 174 Loss = 0.395 Validation loss: 0.258 Train Accuracy = 0.912 Validation Accuracy = 0.938
# EPOCH 175 Loss = 0.391 Validation loss: 0.257 Train Accuracy = 0.912 Validation Accuracy = 0.942
# EPOCH 176 Loss = 0.392 Validation loss: 0.290 Train Accuracy = 0.910 Validation Accuracy = 0.934
# EPOCH 177 Loss = 0.388 Validation loss: 0.279 Train Accuracy = 0.913 Validation Accuracy = 0.931
# EPOCH 178 Loss = 0.383 Validation loss: 0.291 Train Accuracy = 0.914 Validation Accuracy = 0.940
# EPOCH 179 Loss = 0.384 Validation loss: 0.234 Train Accuracy = 0.915 Validation Accuracy = 0.934
# EPOCH 180 Loss = 0.393 Validation loss: 0.292 Train Accuracy = 0.910 Validation Accuracy = 0.942
# EPOCH 181 Loss = 0.386 Validation loss: 0.279 Train Accuracy = 0.914 Validation Accuracy = 0.940
# EPOCH 182 Loss = 0.373 Validation loss: 0.266 Train Accuracy = 0.918 Validation Accuracy = 0.938
# EPOCH 183 Loss = 0.375 Validation loss: 0.253 Train Accuracy = 0.916 Validation Accuracy = 0.942
# EPOCH 184 Loss = 0.371 Validation loss: 0.256 Train Accuracy = 0.919 Validation Accuracy = 0.939
# EPOCH 185 Loss = 0.371 Validation loss: 0.289 Train Accuracy = 0.919 Validation Accuracy = 0.939
# EPOCH 186 Loss = 0.369 Validation loss: 0.236 Train Accuracy = 0.919 Validation Accuracy = 0.942
# EPOCH 187 Loss = 0.364 Validation loss: 0.235 Train Accuracy = 0.923 Validation Accuracy = 0.944
# EPOCH 188 Loss = 0.368 Validation loss: 0.263 Train Accuracy = 0.919 Validation Accuracy = 0.943
# EPOCH 189 Loss = 0.361 Validation loss: 0.225 Train Accuracy = 0.924 Validation Accuracy = 0.944
# EPOCH 190 Loss = 0.363 Validation loss: 0.276 Train Accuracy = 0.921 Validation Accuracy = 0.947
# EPOCH 191 Loss = 0.356 Validation loss: 0.243 Train Accuracy = 0.923 Validation Accuracy = 0.953
# EPOCH 192 Loss = 0.360 Validation loss: 0.229 Train Accuracy = 0.923 Validation Accuracy = 0.946
# EPOCH 193 Loss = 0.358 Validation loss: 0.251 Train Accuracy = 0.924 Validation Accuracy = 0.942
# EPOCH 194 Loss = 0.355 Validation loss: 0.246 Train Accuracy = 0.923 Validation Accuracy = 0.952
# EPOCH 195 Loss = 0.351 Validation loss: 0.250 Train Accuracy = 0.925 Validation Accuracy = 0.941
# EPOCH 196 Loss = 0.346 Validation loss: 0.231 Train Accuracy = 0.928 Validation Accuracy = 0.951
# EPOCH 197 Loss = 0.349 Validation loss: 0.263 Train Accuracy = 0.926 Validation Accuracy = 0.949
# EPOCH 198 Loss = 0.345 Validation loss: 0.228 Train Accuracy = 0.927 Validation Accuracy = 0.947
# EPOCH 199 Loss = 0.349 Validation loss: 0.214 Train Accuracy = 0.925 Validation Accuracy = 0.949
# EPOCH 200 Loss = 0.344 Validation loss: 0.272 Train Accuracy = 0.929 Validation Accuracy = 0.949
# EPOCH 201 Loss = 0.344 Validation loss: 0.212 Train Accuracy = 0.929 Validation Accuracy = 0.946
# EPOCH 202 Loss = 0.344 Validation loss: 0.274 Train Accuracy = 0.928 Validation Accuracy = 0.945
# EPOCH 203 Loss = 0.344 Validation loss: 0.284 Train Accuracy = 0.928 Validation Accuracy = 0.950
# EPOCH 204 Loss = 0.333 Validation loss: 0.210 Train Accuracy = 0.932 Validation Accuracy = 0.955
# EPOCH 205 Loss = 0.335 Validation loss: 0.252 Train Accuracy = 0.932 Validation Accuracy = 0.947
# EPOCH 206 Loss = 0.334 Validation loss: 0.249 Train Accuracy = 0.931 Validation Accuracy = 0.954
# EPOCH 207 Loss = 0.327 Validation loss: 0.212 Train Accuracy = 0.934 Validation Accuracy = 0.955
# EPOCH 208 Loss = 0.331 Validation loss: 0.223 Train Accuracy = 0.932 Validation Accuracy = 0.955
# EPOCH 209 Loss = 0.330 Validation loss: 0.253 Train Accuracy = 0.933 Validation Accuracy = 0.955
# EPOCH 210 Loss = 0.329 Validation loss: 0.211 Train Accuracy = 0.933 Validation Accuracy = 0.948
# EPOCH 211 Loss = 0.321 Validation loss: 0.274 Train Accuracy = 0.934 Validation Accuracy = 0.956
# EPOCH 212 Loss = 0.325 Validation loss: 0.227 Train Accuracy = 0.934 Validation Accuracy = 0.953
# EPOCH 213 Loss = 0.322 Validation loss: 0.230 Train Accuracy = 0.935 Validation Accuracy = 0.955
# EPOCH 214 Loss = 0.315 Validation loss: 0.209 Train Accuracy = 0.937 Validation Accuracy = 0.955
# EPOCH 215 Loss = 0.316 Validation loss: 0.240 Train Accuracy = 0.937 Validation Accuracy = 0.955
# EPOCH 216 Loss = 0.319 Validation loss: 0.212 Train Accuracy = 0.936 Validation Accuracy = 0.947
# EPOCH 217 Loss = 0.315 Validation loss: 0.205 Train Accuracy = 0.937 Validation Accuracy = 0.954
# EPOCH 218 Loss = 0.310 Validation loss: 0.201 Train Accuracy = 0.937 Validation Accuracy = 0.954
# EPOCH 219 Loss = 0.313 Validation loss: 0.235 Train Accuracy = 0.938 Validation Accuracy = 0.955
# EPOCH 220 Loss = 0.315 Validation loss: 0.192 Train Accuracy = 0.937 Validation Accuracy = 0.958
# EPOCH 221 Loss = 0.308 Validation loss: 0.202 Train Accuracy = 0.940 Validation Accuracy = 0.954
# EPOCH 222 Loss = 0.304 Validation loss: 0.213 Train Accuracy = 0.941 Validation Accuracy = 0.961
# EPOCH 223 Loss = 0.303 Validation loss: 0.243 Train Accuracy = 0.941 Validation Accuracy = 0.957
# EPOCH 224 Loss = 0.304 Validation loss: 0.173 Train Accuracy = 0.942 Validation Accuracy = 0.960
# EPOCH 225 Loss = 0.305 Validation loss: 0.214 Train Accuracy = 0.940 Validation Accuracy = 0.953
# EPOCH 226 Loss = 0.300 Validation loss: 0.217 Train Accuracy = 0.942 Validation Accuracy = 0.960
# EPOCH 227 Loss = 0.305 Validation loss: 0.183 Train Accuracy = 0.942 Validation Accuracy = 0.958
# EPOCH 228 Loss = 0.300 Validation loss: 0.194 Train Accuracy = 0.942 Validation Accuracy = 0.959
# EPOCH 229 Loss = 0.300 Validation loss: 0.228 Train Accuracy = 0.941 Validation Accuracy = 0.957
# EPOCH 230 Loss = 0.299 Validation loss: 0.189 Train Accuracy = 0.945 Validation Accuracy = 0.959
# EPOCH 231 Loss = 0.299 Validation loss: 0.180 Train Accuracy = 0.943 Validation Accuracy = 0.960
# EPOCH 232 Loss = 0.291 Validation loss: 0.168 Train Accuracy = 0.945 Validation Accuracy = 0.963
# EPOCH 233 Loss = 0.296 Validation loss: 0.170 Train Accuracy = 0.943 Validation Accuracy = 0.961
# EPOCH 234 Loss = 0.296 Validation loss: 0.189 Train Accuracy = 0.943 Validation Accuracy = 0.958
# EPOCH 235 Loss = 0.285 Validation loss: 0.165 Train Accuracy = 0.947 Validation Accuracy = 0.961
# EPOCH 236 Loss = 0.292 Validation loss: 0.195 Train Accuracy = 0.945 Validation Accuracy = 0.958
# EPOCH 237 Loss = 0.292 Validation loss: 0.178 Train Accuracy = 0.943 Validation Accuracy = 0.962
# EPOCH 238 Loss = 0.288 Validation loss: 0.162 Train Accuracy = 0.946 Validation Accuracy = 0.961
# EPOCH 239 Loss = 0.293 Validation loss: 0.196 Train Accuracy = 0.943 Validation Accuracy = 0.961
# EPOCH 240 Loss = 0.286 Validation loss: 0.167 Train Accuracy = 0.946 Validation Accuracy = 0.960
# EPOCH 241 Loss = 0.284 Validation loss: 0.184 Train Accuracy = 0.946 Validation Accuracy = 0.964
# EPOCH 242 Loss = 0.284 Validation loss: 0.184 Train Accuracy = 0.947 Validation Accuracy = 0.960
# EPOCH 243 Loss = 0.280 Validation loss: 0.176 Train Accuracy = 0.948 Validation Accuracy = 0.962
# EPOCH 244 Loss = 0.282 Validation loss: 0.188 Train Accuracy = 0.948 Validation Accuracy = 0.961
# EPOCH 245 Loss = 0.278 Validation loss: 0.198 Train Accuracy = 0.948 Validation Accuracy = 0.964
# EPOCH 246 Loss = 0.282 Validation loss: 0.204 Train Accuracy = 0.947 Validation Accuracy = 0.961
# EPOCH 247 Loss = 0.284 Validation loss: 0.182 Train Accuracy = 0.948 Validation Accuracy = 0.960
# EPOCH 248 Loss = 0.275 Validation loss: 0.193 Train Accuracy = 0.949 Validation Accuracy = 0.961
# EPOCH 249 Loss = 0.279 Validation loss: 0.194 Train Accuracy = 0.948 Validation Accuracy = 0.962
# EPOCH 250 Loss = 0.277 Validation loss: 0.190 Train Accuracy = 0.948 Validation Accuracy = 0.960
# EPOCH 251 Loss = 0.272 Validation loss: 0.169 Train Accuracy = 0.951 Validation Accuracy = 0.963
# EPOCH 252 Loss = 0.273 Validation loss: 0.185 Train Accuracy = 0.949 Validation Accuracy = 0.962
# EPOCH 253 Loss = 0.277 Validation loss: 0.168 Train Accuracy = 0.949 Validation Accuracy = 0.962
# EPOCH 254 Loss = 0.274 Validation loss: 0.181 Train Accuracy = 0.950 Validation Accuracy = 0.966
# EPOCH 255 Loss = 0.277 Validation loss: 0.175 Train Accuracy = 0.948 Validation Accuracy = 0.963
# EPOCH 256 Loss = 0.272 Validation loss: 0.194 Train Accuracy = 0.951 Validation Accuracy = 0.960
# EPOCH 257 Loss = 0.270 Validation loss: 0.174 Train Accuracy = 0.952 Validation Accuracy = 0.965
# EPOCH 258 Loss = 0.267 Validation loss: 0.172 Train Accuracy = 0.952 Validation Accuracy = 0.963
# EPOCH 259 Loss = 0.267 Validation loss: 0.165 Train Accuracy = 0.953 Validation Accuracy = 0.966
# EPOCH 260 Loss = 0.267 Validation loss: 0.195 Train Accuracy = 0.952 Validation Accuracy = 0.965
# EPOCH 261 Loss = 0.267 Validation loss: 0.152 Train Accuracy = 0.953 Validation Accuracy = 0.963
# EPOCH 262 Loss = 0.266 Validation loss: 0.150 Train Accuracy = 0.953 Validation Accuracy = 0.964
# EPOCH 263 Loss = 0.263 Validation loss: 0.166 Train Accuracy = 0.953 Validation Accuracy = 0.966
# EPOCH 264 Loss = 0.266 Validation loss: 0.186 Train Accuracy = 0.954 Validation Accuracy = 0.963
# EPOCH 265 Loss = 0.258 Validation loss: 0.166 Train Accuracy = 0.956 Validation Accuracy = 0.961
# EPOCH 266 Loss = 0.264 Validation loss: 0.176 Train Accuracy = 0.953 Validation Accuracy = 0.962
# EPOCH 267 Loss = 0.264 Validation loss: 0.172 Train Accuracy = 0.954 Validation Accuracy = 0.964
# EPOCH 268 Loss = 0.262 Validation loss: 0.157 Train Accuracy = 0.954 Validation Accuracy = 0.967
# EPOCH 269 Loss = 0.263 Validation loss: 0.194 Train Accuracy = 0.953 Validation Accuracy = 0.964
# EPOCH 270 Loss = 0.258 Validation loss: 0.168 Train Accuracy = 0.955 Validation Accuracy = 0.963
# EPOCH 271 Loss = 0.259 Validation loss: 0.151 Train Accuracy = 0.956 Validation Accuracy = 0.963
# EPOCH 272 Loss = 0.258 Validation loss: 0.154 Train Accuracy = 0.954 Validation Accuracy = 0.964
# EPOCH 273 Loss = 0.255 Validation loss: 0.175 Train Accuracy = 0.956 Validation Accuracy = 0.968
# EPOCH 274 Loss = 0.255 Validation loss: 0.176 Train Accuracy = 0.955 Validation Accuracy = 0.966
# EPOCH 275 Loss = 0.260 Validation loss: 0.155 Train Accuracy = 0.955 Validation Accuracy = 0.967
# EPOCH 276 Loss = 0.250 Validation loss: 0.168 Train Accuracy = 0.957 Validation Accuracy = 0.968
# EPOCH 277 Loss = 0.252 Validation loss: 0.150 Train Accuracy = 0.958 Validation Accuracy = 0.966
# EPOCH 278 Loss = 0.255 Validation loss: 0.169 Train Accuracy = 0.955 Validation Accuracy = 0.964
# EPOCH 279 Loss = 0.256 Validation loss: 0.173 Train Accuracy = 0.955 Validation Accuracy = 0.967
# EPOCH 280 Loss = 0.250 Validation loss: 0.154 Train Accuracy = 0.956 Validation Accuracy = 0.966
# EPOCH 281 Loss = 0.246 Validation loss: 0.172 Train Accuracy = 0.957 Validation Accuracy = 0.968
# EPOCH 282 Loss = 0.247 Validation loss: 0.154 Train Accuracy = 0.958 Validation Accuracy = 0.966
# EPOCH 283 Loss = 0.250 Validation loss: 0.191 Train Accuracy = 0.957 Validation Accuracy = 0.965
# EPOCH 284 Loss = 0.247 Validation loss: 0.171 Train Accuracy = 0.957 Validation Accuracy = 0.969
# EPOCH 285 Loss = 0.246 Validation loss: 0.173 Train Accuracy = 0.958 Validation Accuracy = 0.966
# EPOCH 286 Loss = 0.245 Validation loss: 0.171 Train Accuracy = 0.958 Validation Accuracy = 0.965
# EPOCH 287 Loss = 0.251 Validation loss: 0.172 Train Accuracy = 0.958 Validation Accuracy = 0.966
# EPOCH 288 Loss = 0.244 Validation loss: 0.182 Train Accuracy = 0.959 Validation Accuracy = 0.963
# EPOCH 289 Loss = 0.247 Validation loss: 0.160 Train Accuracy = 0.959 Validation Accuracy = 0.966
# EPOCH 290 Loss = 0.243 Validation loss: 0.152 Train Accuracy = 0.959 Validation Accuracy = 0.966
# EPOCH 291 Loss = 0.239 Validation loss: 0.154 Train Accuracy = 0.960 Validation Accuracy = 0.965
# EPOCH 292 Loss = 0.240 Validation loss: 0.144 Train Accuracy = 0.960 Validation Accuracy = 0.966
# EPOCH 293 Loss = 0.245 Validation loss: 0.155 Train Accuracy = 0.959 Validation Accuracy = 0.969
# EPOCH 294 Loss = 0.241 Validation loss: 0.156 Train Accuracy = 0.959 Validation Accuracy = 0.968
# EPOCH 295 Loss = 0.241 Validation loss: 0.157 Train Accuracy = 0.959 Validation Accuracy = 0.964
# EPOCH 296 Loss = 0.232 Validation loss: 0.155 Train Accuracy = 0.962 Validation Accuracy = 0.968
# EPOCH 297 Loss = 0.235 Validation loss: 0.179 Train Accuracy = 0.962 Validation Accuracy = 0.968
# EPOCH 298 Loss = 0.241 Validation loss: 0.173 Train Accuracy = 0.959 Validation Accuracy = 0.966
# EPOCH 299 Loss = 0.238 Validation loss: 0.163 Train Accuracy = 0.961 Validation Accuracy = 0.968
# EPOCH 300 Loss = 0.242 Validation loss: 0.169 Train Accuracy = 0.959 Validation Accuracy = 0.967
# EPOCH 301 Loss = 0.235 Validation loss: 0.154 Train Accuracy = 0.963 Validation Accuracy = 0.966
# EPOCH 302 Loss = 0.235 Validation loss: 0.174 Train Accuracy = 0.962 Validation Accuracy = 0.967
# EPOCH 303 Loss = 0.237 Validation loss: 0.145 Train Accuracy = 0.961 Validation Accuracy = 0.969
# EPOCH 304 Loss = 0.233 Validation loss: 0.158 Train Accuracy = 0.962 Validation Accuracy = 0.970
# EPOCH 305 Loss = 0.235 Validation loss: 0.168 Train Accuracy = 0.960 Validation Accuracy = 0.969
# EPOCH 306 Loss = 0.234 Validation loss: 0.148 Train Accuracy = 0.961 Validation Accuracy = 0.966
# EPOCH 307 Loss = 0.233 Validation loss: 0.159 Train Accuracy = 0.962 Validation Accuracy = 0.968
# EPOCH 308 Loss = 0.232 Validation loss: 0.163 Train Accuracy = 0.962 Validation Accuracy = 0.966
# EPOCH 309 Loss = 0.231 Validation loss: 0.150 Train Accuracy = 0.963 Validation Accuracy = 0.969
# EPOCH 310 Loss = 0.228 Validation loss: 0.160 Train Accuracy = 0.964 Validation Accuracy = 0.968
# EPOCH 311 Loss = 0.225 Validation loss: 0.138 Train Accuracy = 0.965 Validation Accuracy = 0.969
# EPOCH 312 Loss = 0.228 Validation loss: 0.157 Train Accuracy = 0.963 Validation Accuracy = 0.969
# EPOCH 313 Loss = 0.228 Validation loss: 0.147 Train Accuracy = 0.963 Validation Accuracy = 0.968
# EPOCH 314 Loss = 0.225 Validation loss: 0.148 Train Accuracy = 0.963 Validation Accuracy = 0.968
# EPOCH 315 Loss = 0.224 Validation loss: 0.143 Train Accuracy = 0.965 Validation Accuracy = 0.970
# EPOCH 316 Loss = 0.219 Validation loss: 0.148 Train Accuracy = 0.965 Validation Accuracy = 0.967
# EPOCH 317 Loss = 0.225 Validation loss: 0.155 Train Accuracy = 0.965 Validation Accuracy = 0.971
# EPOCH 318 Loss = 0.226 Validation loss: 0.179 Train Accuracy = 0.964 Validation Accuracy = 0.971
# EPOCH 319 Loss = 0.223 Validation loss: 0.143 Train Accuracy = 0.965 Validation Accuracy = 0.968
# EPOCH 320 Loss = 0.220 Validation loss: 0.159 Train Accuracy = 0.966 Validation Accuracy = 0.968
# EPOCH 321 Loss = 0.220 Validation loss: 0.143 Train Accuracy = 0.965 Validation Accuracy = 0.970
# EPOCH 322 Loss = 0.223 Validation loss: 0.164 Train Accuracy = 0.965 Validation Accuracy = 0.970
# EPOCH 323 Loss = 0.220 Validation loss: 0.146 Train Accuracy = 0.965 Validation Accuracy = 0.970
# EPOCH 324 Loss = 0.227 Validation loss: 0.149 Train Accuracy = 0.964 Validation Accuracy = 0.969
# EPOCH 325 Loss = 0.219 Validation loss: 0.133 Train Accuracy = 0.965 Validation Accuracy = 0.968
# EPOCH 326 Loss = 0.218 Validation loss: 0.156 Train Accuracy = 0.967 Validation Accuracy = 0.970
# EPOCH 327 Loss = 0.219 Validation loss: 0.154 Train Accuracy = 0.966 Validation Accuracy = 0.968
# EPOCH 328 Loss = 0.219 Validation loss: 0.153 Train Accuracy = 0.967 Validation Accuracy = 0.970
# EPOCH 329 Loss = 0.217 Validation loss: 0.143 Train Accuracy = 0.966 Validation Accuracy = 0.968
# EPOCH 330 Loss = 0.215 Validation loss: 0.134 Train Accuracy = 0.967 Validation Accuracy = 0.971
# EPOCH 331 Loss = 0.215 Validation loss: 0.150 Train Accuracy = 0.969 Validation Accuracy = 0.970
# EPOCH 332 Loss = 0.220 Validation loss: 0.152 Train Accuracy = 0.965 Validation Accuracy = 0.966
# EPOCH 333 Loss = 0.215 Validation loss: 0.144 Train Accuracy = 0.967 Validation Accuracy = 0.970
# EPOCH 334 Loss = 0.218 Validation loss: 0.141 Train Accuracy = 0.966 Validation Accuracy = 0.970
# EPOCH 335 Loss = 0.215 Validation loss: 0.153 Train Accuracy = 0.967 Validation Accuracy = 0.968
# EPOCH 336 Loss = 0.220 Validation loss: 0.154 Train Accuracy = 0.966 Validation Accuracy = 0.971
# EPOCH 337 Loss = 0.217 Validation loss: 0.143 Train Accuracy = 0.968 Validation Accuracy = 0.969
# EPOCH 338 Loss = 0.215 Validation loss: 0.139 Train Accuracy = 0.966 Validation Accuracy = 0.972
# EPOCH 339 Loss = 0.216 Validation loss: 0.142 Train Accuracy = 0.966 Validation Accuracy = 0.971
# EPOCH 340 Loss = 0.213 Validation loss: 0.142 Train Accuracy = 0.967 Validation Accuracy = 0.972
# EPOCH 341 Loss = 0.210 Validation loss: 0.139 Train Accuracy = 0.967 Validation Accuracy = 0.970
# EPOCH 342 Loss = 0.213 Validation loss: 0.143 Train Accuracy = 0.968 Validation Accuracy = 0.971
# EPOCH 343 Loss = 0.210 Validation loss: 0.162 Train Accuracy = 0.969 Validation Accuracy = 0.968
# EPOCH 344 Loss = 0.210 Validation loss: 0.136 Train Accuracy = 0.968 Validation Accuracy = 0.971
# EPOCH 345 Loss = 0.210 Validation loss: 0.143 Train Accuracy = 0.968 Validation Accuracy = 0.971
# EPOCH 346 Loss = 0.210 Validation loss: 0.134 Train Accuracy = 0.969 Validation Accuracy = 0.970
# EPOCH 347 Loss = 0.207 Validation loss: 0.135 Train Accuracy = 0.969 Validation Accuracy = 0.972
# EPOCH 348 Loss = 0.211 Validation loss: 0.138 Train Accuracy = 0.968 Validation Accuracy = 0.971
# EPOCH 349 Loss = 0.209 Validation loss: 0.131 Train Accuracy = 0.970 Validation Accuracy = 0.970
# EPOCH 350 Loss = 0.209 Validation loss: 0.134 Train Accuracy = 0.969 Validation Accuracy = 0.972
# EPOCH 351 Loss = 0.206 Validation loss: 0.127 Train Accuracy = 0.970 Validation Accuracy = 0.971
# EPOCH 352 Loss = 0.207 Validation loss: 0.167 Train Accuracy = 0.969 Validation Accuracy = 0.968
# EPOCH 353 Loss = 0.208 Validation loss: 0.134 Train Accuracy = 0.968 Validation Accuracy = 0.970
# EPOCH 354 Loss = 0.207 Validation loss: 0.138 Train Accuracy = 0.969 Validation Accuracy = 0.971
# EPOCH 355 Loss = 0.208 Validation loss: 0.132 Train Accuracy = 0.969 Validation Accuracy = 0.970
# EPOCH 356 Loss = 0.206 Validation loss: 0.138 Train Accuracy = 0.970 Validation Accuracy = 0.972
# EPOCH 357 Loss = 0.202 Validation loss: 0.133 Train Accuracy = 0.971 Validation Accuracy = 0.972
# EPOCH 358 Loss = 0.205 Validation loss: 0.140 Train Accuracy = 0.970 Validation Accuracy = 0.971
# EPOCH 359 Loss = 0.203 Validation loss: 0.138 Train Accuracy = 0.970 Validation Accuracy = 0.968
# EPOCH 360 Loss = 0.202 Validation loss: 0.133 Train Accuracy = 0.969 Validation Accuracy = 0.969
# EPOCH 361 Loss = 0.200 Validation loss: 0.134 Train Accuracy = 0.971 Validation Accuracy = 0.973
# EPOCH 362 Loss = 0.200 Validation loss: 0.133 Train Accuracy = 0.971 Validation Accuracy = 0.972
# EPOCH 363 Loss = 0.203 Validation loss: 0.129 Train Accuracy = 0.970 Validation Accuracy = 0.973
# EPOCH 364 Loss = 0.198 Validation loss: 0.137 Train Accuracy = 0.971 Validation Accuracy = 0.971
# EPOCH 365 Loss = 0.199 Validation loss: 0.141 Train Accuracy = 0.971 Validation Accuracy = 0.971
# EPOCH 366 Loss = 0.197 Validation loss: 0.135 Train Accuracy = 0.972 Validation Accuracy = 0.970
# EPOCH 367 Loss = 0.201 Validation loss: 0.132 Train Accuracy = 0.971 Validation Accuracy = 0.974
# EPOCH 368 Loss = 0.200 Validation loss: 0.145 Train Accuracy = 0.971 Validation Accuracy = 0.974
# EPOCH 369 Loss = 0.198 Validation loss: 0.137 Train Accuracy = 0.971 Validation Accuracy = 0.971
# EPOCH 370 Loss = 0.200 Validation loss: 0.120 Train Accuracy = 0.971 Validation Accuracy = 0.971
# EPOCH 371 Loss = 0.198 Validation loss: 0.133 Train Accuracy = 0.971 Validation Accuracy = 0.972
# EPOCH 372 Loss = 0.198 Validation loss: 0.133 Train Accuracy = 0.971 Validation Accuracy = 0.973
# EPOCH 373 Loss = 0.198 Validation loss: 0.137 Train Accuracy = 0.970 Validation Accuracy = 0.971
# EPOCH 374 Loss = 0.193 Validation loss: 0.125 Train Accuracy = 0.972 Validation Accuracy = 0.973
# EPOCH 375 Loss = 0.197 Validation loss: 0.127 Train Accuracy = 0.971 Validation Accuracy = 0.973
# EPOCH 376 Loss = 0.197 Validation loss: 0.138 Train Accuracy = 0.974 Validation Accuracy = 0.973
# EPOCH 377 Loss = 0.199 Validation loss: 0.141 Train Accuracy = 0.971 Validation Accuracy = 0.972
# EPOCH 378 Loss = 0.196 Validation loss: 0.139 Train Accuracy = 0.972 Validation Accuracy = 0.972
# EPOCH 379 Loss = 0.194 Validation loss: 0.132 Train Accuracy = 0.972 Validation Accuracy = 0.974
# EPOCH 380 Loss = 0.193 Validation loss: 0.141 Train Accuracy = 0.973 Validation Accuracy = 0.975
# EPOCH 381 Loss = 0.194 Validation loss: 0.136 Train Accuracy = 0.972 Validation Accuracy = 0.970
# EPOCH 382 Loss = 0.190 Validation loss: 0.129 Train Accuracy = 0.973 Validation Accuracy = 0.973
# EPOCH 383 Loss = 0.195 Validation loss: 0.128 Train Accuracy = 0.971 Validation Accuracy = 0.972
# EPOCH 384 Loss = 0.190 Validation loss: 0.131 Train Accuracy = 0.974 Validation Accuracy = 0.973
# EPOCH 385 Loss = 0.193 Validation loss: 0.122 Train Accuracy = 0.973 Validation Accuracy = 0.973
# EPOCH 386 Loss = 0.191 Validation loss: 0.130 Train Accuracy = 0.974 Validation Accuracy = 0.972
# EPOCH 387 Loss = 0.194 Validation loss: 0.136 Train Accuracy = 0.973 Validation Accuracy = 0.972
# EPOCH 388 Loss = 0.190 Validation loss: 0.133 Train Accuracy = 0.973 Validation Accuracy = 0.970
# EPOCH 389 Loss = 0.192 Validation loss: 0.137 Train Accuracy = 0.972 Validation Accuracy = 0.974
# EPOCH 390 Loss = 0.188 Validation loss: 0.139 Train Accuracy = 0.974 Validation Accuracy = 0.973
# EPOCH 391 Loss = 0.187 Validation loss: 0.130 Train Accuracy = 0.975 Validation Accuracy = 0.972
# EPOCH 392 Loss = 0.193 Validation loss: 0.138 Train Accuracy = 0.973 Validation Accuracy = 0.972
# EPOCH 393 Loss = 0.191 Validation loss: 0.130 Train Accuracy = 0.973 Validation Accuracy = 0.974
# EPOCH 394 Loss = 0.189 Validation loss: 0.129 Train Accuracy = 0.974 Validation Accuracy = 0.973
# EPOCH 395 Loss = 0.187 Validation loss: 0.124 Train Accuracy = 0.974 Validation Accuracy = 0.974
# EPOCH 396 Loss = 0.185 Validation loss: 0.139 Train Accuracy = 0.975 Validation Accuracy = 0.975
# EPOCH 397 Loss = 0.193 Validation loss: 0.123 Train Accuracy = 0.973 Validation Accuracy = 0.971
# EPOCH 398 Loss = 0.189 Validation loss: 0.120 Train Accuracy = 0.974 Validation Accuracy = 0.974
# EPOCH 399 Loss = 0.185 Validation loss: 0.135 Train Accuracy = 0.974 Validation Accuracy = 0.975
# EPOCH 400 Loss = 0.187 Validation loss: 0.120 Train Accuracy = 0.974 Validation Accuracy = 0.974
# EPOCH 401 Loss = 0.186 Validation loss: 0.129 Train Accuracy = 0.975 Validation Accuracy = 0.973
# EPOCH 402 Loss = 0.186 Validation loss: 0.125 Train Accuracy = 0.975 Validation Accuracy = 0.975
# EPOCH 403 Loss = 0.187 Validation loss: 0.125 Train Accuracy = 0.974 Validation Accuracy = 0.971
# EPOCH 404 Loss = 0.189 Validation loss: 0.133 Train Accuracy = 0.974 Validation Accuracy = 0.971
# EPOCH 405 Loss = 0.184 Validation loss: 0.139 Train Accuracy = 0.975 Validation Accuracy = 0.974
# EPOCH 406 Loss = 0.182 Validation loss: 0.129 Train Accuracy = 0.976 Validation Accuracy = 0.971
# EPOCH 407 Loss = 0.181 Validation loss: 0.120 Train Accuracy = 0.975 Validation Accuracy = 0.975
# EPOCH 408 Loss = 0.184 Validation loss: 0.126 Train Accuracy = 0.975 Validation Accuracy = 0.974
# EPOCH 409 Loss = 0.183 Validation loss: 0.129 Train Accuracy = 0.976 Validation Accuracy = 0.972
# EPOCH 410 Loss = 0.182 Validation loss: 0.126 Train Accuracy = 0.976 Validation Accuracy = 0.976
# EPOCH 411 Loss = 0.184 Validation loss: 0.126 Train Accuracy = 0.975 Validation Accuracy = 0.977
# EPOCH 412 Loss = 0.187 Validation loss: 0.138 Train Accuracy = 0.974 Validation Accuracy = 0.974
# EPOCH 413 Loss = 0.180 Validation loss: 0.143 Train Accuracy = 0.976 Validation Accuracy = 0.974
# EPOCH 414 Loss = 0.184 Validation loss: 0.128 Train Accuracy = 0.975 Validation Accuracy = 0.975
# EPOCH 415 Loss = 0.184 Validation loss: 0.135 Train Accuracy = 0.976 Validation Accuracy = 0.973
# EPOCH 416 Loss = 0.178 Validation loss: 0.147 Train Accuracy = 0.977 Validation Accuracy = 0.974
# EPOCH 417 Loss = 0.177 Validation loss: 0.124 Train Accuracy = 0.977 Validation Accuracy = 0.973
# EPOCH 418 Loss = 0.183 Validation loss: 0.129 Train Accuracy = 0.975 Validation Accuracy = 0.972
# EPOCH 419 Loss = 0.179 Validation loss: 0.128 Train Accuracy = 0.976 Validation Accuracy = 0.975
# EPOCH 420 Loss = 0.180 Validation loss: 0.126 Train Accuracy = 0.976 Validation Accuracy = 0.973
# EPOCH 421 Loss = 0.185 Validation loss: 0.159 Train Accuracy = 0.974 Validation Accuracy = 0.973
# EPOCH 422 Loss = 0.182 Validation loss: 0.128 Train Accuracy = 0.976 Validation Accuracy = 0.977
# EPOCH 423 Loss = 0.181 Validation loss: 0.132 Train Accuracy = 0.975 Validation Accuracy = 0.976
# EPOCH 424 Loss = 0.181 Validation loss: 0.125 Train Accuracy = 0.975 Validation Accuracy = 0.974
# EPOCH 425 Loss = 0.178 Validation loss: 0.133 Train Accuracy = 0.977 Validation Accuracy = 0.971
# EPOCH 426 Loss = 0.179 Validation loss: 0.135 Train Accuracy = 0.976 Validation Accuracy = 0.974
# EPOCH 427 Loss = 0.181 Validation loss: 0.127 Train Accuracy = 0.975 Validation Accuracy = 0.973
# EPOCH 428 Loss = 0.179 Validation loss: 0.119 Train Accuracy = 0.976 Validation Accuracy = 0.973
# EPOCH 429 Loss = 0.177 Validation loss: 0.123 Train Accuracy = 0.976 Validation Accuracy = 0.971
# EPOCH 430 Loss = 0.176 Validation loss: 0.135 Train Accuracy = 0.977 Validation Accuracy = 0.972
# EPOCH 431 Loss = 0.177 Validation loss: 0.131 Train Accuracy = 0.976 Validation Accuracy = 0.972
# EPOCH 432 Loss = 0.175 Validation loss: 0.116 Train Accuracy = 0.977 Validation Accuracy = 0.974
# EPOCH 433 Loss = 0.175 Validation loss: 0.140 Train Accuracy = 0.977 Validation Accuracy = 0.974
# EPOCH 434 Loss = 0.176 Validation loss: 0.133 Train Accuracy = 0.977 Validation Accuracy = 0.976
# EPOCH 435 Loss = 0.177 Validation loss: 0.118 Train Accuracy = 0.977 Validation Accuracy = 0.975
# EPOCH 436 Loss = 0.177 Validation loss: 0.128 Train Accuracy = 0.976 Validation Accuracy = 0.974
# EPOCH 437 Loss = 0.175 Validation loss: 0.119 Train Accuracy = 0.976 Validation Accuracy = 0.973
# EPOCH 438 Loss = 0.177 Validation loss: 0.130 Train Accuracy = 0.976 Validation Accuracy = 0.974
# EPOCH 439 Loss = 0.174 Validation loss: 0.122 Train Accuracy = 0.976 Validation Accuracy = 0.974
# EPOCH 440 Loss = 0.171 Validation loss: 0.127 Train Accuracy = 0.979 Validation Accuracy = 0.973
# EPOCH 441 Loss = 0.176 Validation loss: 0.128 Train Accuracy = 0.977 Validation Accuracy = 0.973
# EPOCH 442 Loss = 0.171 Validation loss: 0.138 Train Accuracy = 0.978 Validation Accuracy = 0.973
# EPOCH 443 Loss = 0.172 Validation loss: 0.120 Train Accuracy = 0.978 Validation Accuracy = 0.973
# EPOCH 444 Loss = 0.172 Validation loss: 0.120 Train Accuracy = 0.978 Validation Accuracy = 0.972
# EPOCH 445 Loss = 0.175 Validation loss: 0.132 Train Accuracy = 0.977 Validation Accuracy = 0.976
# EPOCH 446 Loss = 0.175 Validation loss: 0.127 Train Accuracy = 0.977 Validation Accuracy = 0.972
# EPOCH 447 Loss = 0.175 Validation loss: 0.126 Train Accuracy = 0.977 Validation Accuracy = 0.974
# EPOCH 448 Loss = 0.170 Validation loss: 0.122 Train Accuracy = 0.978 Validation Accuracy = 0.974
# EPOCH 449 Loss = 0.171 Validation loss: 0.111 Train Accuracy = 0.978 Validation Accuracy = 0.974
# EPOCH 450 Loss = 0.170 Validation loss: 0.127 Train Accuracy = 0.978 Validation Accuracy = 0.975
# EPOCH 451 Loss = 0.170 Validation loss: 0.131 Train Accuracy = 0.979 Validation Accuracy = 0.976
# EPOCH 452 Loss = 0.173 Validation loss: 0.151 Train Accuracy = 0.977 Validation Accuracy = 0.974
# EPOCH 453 Loss = 0.175 Validation loss: 0.121 Train Accuracy = 0.977 Validation Accuracy = 0.977
# EPOCH 454 Loss = 0.170 Validation loss: 0.117 Train Accuracy = 0.978 Validation Accuracy = 0.976
# EPOCH 455 Loss = 0.168 Validation loss: 0.124 Train Accuracy = 0.979 Validation Accuracy = 0.977
# EPOCH 456 Loss = 0.167 Validation loss: 0.115 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 457 Loss = 0.168 Validation loss: 0.113 Train Accuracy = 0.978 Validation Accuracy = 0.973
# EPOCH 458 Loss = 0.172 Validation loss: 0.117 Train Accuracy = 0.977 Validation Accuracy = 0.976
# EPOCH 459 Loss = 0.169 Validation loss: 0.121 Train Accuracy = 0.979 Validation Accuracy = 0.972
# EPOCH 460 Loss = 0.173 Validation loss: 0.111 Train Accuracy = 0.977 Validation Accuracy = 0.975
# EPOCH 461 Loss = 0.169 Validation loss: 0.112 Train Accuracy = 0.979 Validation Accuracy = 0.974
# EPOCH 462 Loss = 0.170 Validation loss: 0.123 Train Accuracy = 0.978 Validation Accuracy = 0.975
# EPOCH 463 Loss = 0.165 Validation loss: 0.121 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 464 Loss = 0.168 Validation loss: 0.121 Train Accuracy = 0.979 Validation Accuracy = 0.977
# EPOCH 465 Loss = 0.167 Validation loss: 0.112 Train Accuracy = 0.980 Validation Accuracy = 0.973
# EPOCH 466 Loss = 0.167 Validation loss: 0.116 Train Accuracy = 0.979 Validation Accuracy = 0.975
# EPOCH 467 Loss = 0.171 Validation loss: 0.124 Train Accuracy = 0.977 Validation Accuracy = 0.973
# EPOCH 468 Loss = 0.168 Validation loss: 0.113 Train Accuracy = 0.978 Validation Accuracy = 0.976
# EPOCH 469 Loss = 0.165 Validation loss: 0.114 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 470 Loss = 0.165 Validation loss: 0.114 Train Accuracy = 0.980 Validation Accuracy = 0.976
# EPOCH 471 Loss = 0.166 Validation loss: 0.121 Train Accuracy = 0.979 Validation Accuracy = 0.974
# EPOCH 472 Loss = 0.165 Validation loss: 0.120 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 473 Loss = 0.162 Validation loss: 0.114 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 474 Loss = 0.163 Validation loss: 0.114 Train Accuracy = 0.980 Validation Accuracy = 0.973
# EPOCH 475 Loss = 0.166 Validation loss: 0.131 Train Accuracy = 0.979 Validation Accuracy = 0.976
# EPOCH 476 Loss = 0.164 Validation loss: 0.125 Train Accuracy = 0.979 Validation Accuracy = 0.974
# EPOCH 477 Loss = 0.165 Validation loss: 0.113 Train Accuracy = 0.980 Validation Accuracy = 0.975
# EPOCH 478 Loss = 0.164 Validation loss: 0.118 Train Accuracy = 0.979 Validation Accuracy = 0.974
# EPOCH 479 Loss = 0.164 Validation loss: 0.119 Train Accuracy = 0.979 Validation Accuracy = 0.975
# EPOCH 480 Loss = 0.165 Validation loss: 0.122 Train Accuracy = 0.979 Validation Accuracy = 0.973
# EPOCH 481 Loss = 0.163 Validation loss: 0.121 Train Accuracy = 0.979 Validation Accuracy = 0.975
# EPOCH 482 Loss = 0.159 Validation loss: 0.111 Train Accuracy = 0.980 Validation Accuracy = 0.975
# EPOCH 483 Loss = 0.163 Validation loss: 0.115 Train Accuracy = 0.980 Validation Accuracy = 0.975
# EPOCH 484 Loss = 0.167 Validation loss: 0.139 Train Accuracy = 0.978 Validation Accuracy = 0.975
# EPOCH 485 Loss = 0.163 Validation loss: 0.122 Train Accuracy = 0.980 Validation Accuracy = 0.977
# EPOCH 486 Loss = 0.161 Validation loss: 0.122 Train Accuracy = 0.980 Validation Accuracy = 0.975
# EPOCH 487 Loss = 0.162 Validation loss: 0.118 Train Accuracy = 0.981 Validation Accuracy = 0.974
# EPOCH 488 Loss = 0.159 Validation loss: 0.112 Train Accuracy = 0.980 Validation Accuracy = 0.977
# EPOCH 489 Loss = 0.161 Validation loss: 0.125 Train Accuracy = 0.981 Validation Accuracy = 0.976
# EPOCH 490 Loss = 0.161 Validation loss: 0.110 Train Accuracy = 0.980 Validation Accuracy = 0.974
# EPOCH 491 Loss = 0.159 Validation loss: 0.116 Train Accuracy = 0.981 Validation Accuracy = 0.975
# EPOCH 492 Loss = 0.164 Validation loss: 0.110 Train Accuracy = 0.980 Validation Accuracy = 0.975
# EPOCH 493 Loss = 0.160 Validation loss: 0.121 Train Accuracy = 0.981 Validation Accuracy = 0.975
# EPOCH 494 Loss = 0.162 Validation loss: 0.121 Train Accuracy = 0.980 Validation Accuracy = 0.976
# EPOCH 495 Loss = 0.161 Validation loss: 0.123 Train Accuracy = 0.980 Validation Accuracy = 0.969
# EPOCH 496 Loss = 0.161 Validation loss: 0.111 Train Accuracy = 0.980 Validation Accuracy = 0.977
# EPOCH 497 Loss = 0.161 Validation loss: 0.115 Train Accuracy = 0.981 Validation Accuracy = 0.975
# EPOCH 498 Loss = 0.159 Validation loss: 0.115 Train Accuracy = 0.981 Validation Accuracy = 0.976
# EPOCH 499 Loss = 0.159 Validation loss: 0.117 Train Accuracy = 0.981 Validation Accuracy = 0.974
# EPOCH 500 Loss = 0.158 Validation loss: 0.109 Train Accuracy = 0.980 Validation Accuracy = 0.976
# Final model saved

# %%
#Final test on hold-out test set
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('./lenetmodel/'))

    test_accuracy, loss = evaluate(X_test_normalized, y_test)
    print("Test Accuracy = {:.3f}, Test Loss = {:.3f}".format(test_accuracy, loss))
# Out:
# INFO:tensorflow:Restoring parameters from ./lenetmodel/lenet
# Test Accuracy = 0.970, Test Loss = 0.275

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir('./web_examples/') if isfile(join('./web_examples/', f))]

# %%
import scipy
imgs = []
for f in onlyfiles:
    img = scipy.ndimage.imread(join('./web_examples/', f))
    img = scipy.misc.imresize(img, (32,32))
    imgs.append(img)
# Out:
# /home/xnguyen/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   after removing the cwd from sys.path.
# /home/xnguyen/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """

# %%
plt.figure(figsize=(10,10))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(imgs[i])

# %%
imgs_normalized = np.asarray(imgs)
imgs_normalized = (imgs_normalized - 128.)/128.
imgs_normalized.shape
# Out:
# (5, 32, 32, 3)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.
def predict(X_data):
    sess = tf.get_default_session()
    
    probs = sess.run(logits, feed_dict={x: X_data, prob: 1})       
    return probs

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('./lenetmodel/'))
    probs = predict(imgs_normalized)
# Out:
# INFO:tensorflow:Restoring parameters from ./lenetmodel/lenet

# %%
#read label description
import pandas as pd
label_desc=pd.read_csv('signnames.csv', sep=',')

label = np.argmax(probs,axis =1)
print(label)
# Out:
# [14 25  1  4 17]

# %%
plt.figure(figsize=(20,20))
for i in range(5):
    plt.subplot(5,1,i+1)
    plt.imshow(imgs[i])
    plt.title(label_desc.ix[label[i]][1])

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.
# Accuracy is 80%

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.
top_k = tf.nn.top_k(tf.nn.softmax(logits), k=5)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('./lenetmodel/'))
    top_k_prob = sess.run(top_k,feed_dict={x: imgs_normalized, prob: 1})
# Out:
# INFO:tensorflow:Restoring parameters from ./lenetmodel/lenet

# %%
plt.figure(figsize=(10,20))
for i in range(len(label)):
    plt.subplot(len(label),1,i+1)
    plt.imshow(imgs[i])
    title = ''
    for j in range(5):
        title += 'Label %d: %s (%.2f%%) '%(j, label_desc.ix[top_k_prob[1][i][j]][1], 100.*top_k_prob[0][i][j])
    plt.title(title)

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")

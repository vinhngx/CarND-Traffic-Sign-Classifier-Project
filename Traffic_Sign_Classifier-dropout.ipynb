# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = 'data/train.p'
validation_file= 'data/valid.p'
testing_file = 'data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
import numpy as np

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train.shape[1:3]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of validation examples =", n_validation)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of validation examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
#plot class distribution across different sets
plt.figure;
plt.subplot(1,3,1)
plt.hist(y_train, 43);
plt.subplot(1,3,2)
plt.hist(y_valid, 43);
plt.subplot(1,3,3)
plt.hist(y_test, 43);

# %%
#plot a random selection of images belonging to a class
for class_id in range(43):
    items = np.argwhere(y_train==class_id)
    np.random.shuffle(items)
    plt.figure(figsize=(20,4))    
    for i in range(10):
        plt.subplot(1,10,i+1)
        plt.imshow(X_train[items[i][0],:])
        plt.title('Class %d'%class_id)
        plt.axis('off')
    plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.
X_train_normalized = (X_train - 128.)/128
X_test_normalized = (X_test - 128.)/128
X_valid_normalized = (X_valid - 128.)/128

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
from tensorflow.contrib.layers import flatten
import tensorflow as tf

def LeNet(x, prob):  
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 32x32x16.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 3, 16), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(16))
    x       = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='SAME') + conv1_b
    x       = tf.nn.relu(x)
    
    L2_regularizer = tf.nn.l2_loss(conv1_W) + tf.nn.l2_loss(conv1_b)
    
    # SOLUTION: Layer 12: Convolutional. Input = 32x32x16. Output = 32x32x16.
    conv12_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 16), mean = mu, stddev = sigma))
    conv12_b = tf.Variable(tf.zeros(16))
    x        = tf.nn.conv2d(x, conv12_W, strides=[1, 1, 1, 1], padding='SAME') + conv12_b
    x        = tf.nn.relu(x)
    
    L2_regularizer += tf.nn.l2_loss(conv12_W) + tf.nn.l2_loss(conv12_b)
    
    # SOLUTION: Pooling. Input = 32x32x16. Output = 16x16x16.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 16x16x32.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 32), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(32))
    x       = tf.nn.conv2d(x, conv2_W, strides=[1, 1, 1, 1], padding='SAME') + conv2_b
    x       = tf.nn.relu(x)
    #x       = tf.nn.dropout(x, keep_prob=0.5)
    
    L2_regularizer += tf.nn.l2_loss(conv2_W) + tf.nn.l2_loss(conv2_b)
    
    # SOLUTION: Layer 22: Convolutional. Input = 16x16x32. Output = 16x16x64.
    conv22_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 32, 64), mean = mu, stddev = sigma))
    conv22_b = tf.Variable(tf.zeros(64))
    x        = tf.nn.conv2d(x, conv22_W, strides=[1, 1, 1, 1], padding='SAME') + conv22_b
    x        = tf.nn.relu(x)
    #x        = tf.nn.dropout(x, keep_prob=0.5)
    
    L2_regularizer += tf.nn.l2_loss(conv22_W) + tf.nn.l2_loss(conv22_b)
    
    
    # SOLUTION: Pooling. Input = 16x16x64. Output = 8x8x64.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    # Global average pooling layer
    x = tf.reduce_mean(x, [1,2])
    
    # SOLUTION: Flatten. Input = 64. Output = 64.
    x    = flatten(x)
    x    = tf.nn.dropout(x, keep_prob=prob)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 64. Output = 43.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(64, 43), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(43))
    x   = tf.matmul(x, fc1_W) + fc1_b
    
    L2_regularizer += tf.nn.l2_loss(fc1_W) + tf.nn.l2_loss(fc1_b)
    
    return x, L2_regularizer

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 3))
y = tf.placeholder(tf.int32, (None))
prob = tf.placeholder(tf.float32, name='keep_prob')

one_hot_y = tf.one_hot(y, 43)

rate = 0.01

logits, L2_regularizer = LeNet(x, prob)
L2_REGULARIZER = 1e-4

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits) + L2_REGULARIZER*L2_regularizer
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, prob: 1})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
from sklearn.utils import shuffle

EPOCHS=200
BATCH_SIZE = 1024

acc_arr = []
loss_arr = []
val_acc_arr = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train_normalized)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train_normalized, y_train = shuffle(X_train_normalized, y_train)

        ep_acc_arr = []
        ep_loss_arr = []        
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train_normalized[offset:end], y_train[offset:end]
            _, loss, acc = sess.run([training_operation, loss_operation, accuracy_operation], 
                                    feed_dict={x: batch_x, y: batch_y, prob: 0.2})
            #sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            ep_loss_arr.append(loss)
            ep_acc_arr.append(acc)
        
        acc_arr.append(np.mean(ep_acc_arr))
        loss_arr.append(np.mean(ep_loss_arr))
        validation_accuracy = evaluate(X_valid_normalized, y_valid)
        val_acc_arr.append(validation_accuracy)
        print("EPOCH {} ...".format(i+1))
        print("Loss = {:.3f} Train Accuracy = {:.3f} Validation Accuracy = {:.3f}".format(loss_arr[-1], acc_arr[-1], validation_accuracy))
        print()
        
    saver.save(sess, './lenet')
    print("Model saved")
plt.plot(loss_arr)
plt.plot(acc_arr)
plt.plot(val_acc_arr)
plt.legend(['Loss', 'Train Accuracy', 'Validation Accuracy'])
# Out:
# Training...
#
# EPOCH 1 ...
# Loss = 3.504 Train Accuracy = 0.075 Validation Accuracy = 0.098
#
# EPOCH 2 ...
# Loss = 3.298 Train Accuracy = 0.105 Validation Accuracy = 0.092
#
# EPOCH 3 ...
# Loss = 3.220 Train Accuracy = 0.116 Validation Accuracy = 0.096
#
# EPOCH 4 ...
# Loss = 3.152 Train Accuracy = 0.120 Validation Accuracy = 0.118
#
# EPOCH 5 ...
# Loss = 3.172 Train Accuracy = 0.117 Validation Accuracy = 0.134
#
# EPOCH 6 ...
# Loss = 3.150 Train Accuracy = 0.122 Validation Accuracy = 0.087
#
# EPOCH 7 ...
# Loss = 3.126 Train Accuracy = 0.130 Validation Accuracy = 0.163
#
# EPOCH 8 ...
# Loss = 3.062 Train Accuracy = 0.142 Validation Accuracy = 0.159
#
# EPOCH 9 ...
# Loss = 2.875 Train Accuracy = 0.181 Validation Accuracy = 0.207
#
# EPOCH 10 ...
# Loss = 2.687 Train Accuracy = 0.208 Validation Accuracy = 0.259
#
# EPOCH 11 ...
# Loss = 2.516 Train Accuracy = 0.248 Validation Accuracy = 0.323
#
# EPOCH 12 ...
# Loss = 2.394 Train Accuracy = 0.274 Validation Accuracy = 0.329
#
# EPOCH 13 ...
# Loss = 2.356 Train Accuracy = 0.292 Validation Accuracy = 0.366
#
# EPOCH 14 ...
# Loss = 2.227 Train Accuracy = 0.322 Validation Accuracy = 0.435
#
# EPOCH 15 ...
# Loss = 2.156 Train Accuracy = 0.343 Validation Accuracy = 0.478
#
# EPOCH 16 ...
# Loss = 2.083 Train Accuracy = 0.364 Validation Accuracy = 0.490
#
# EPOCH 17 ...
# Loss = 2.039 Train Accuracy = 0.376 Validation Accuracy = 0.515
#
# EPOCH 18 ...
# Loss = 1.982 Train Accuracy = 0.394 Validation Accuracy = 0.562
#
# EPOCH 19 ...
# Loss = 1.939 Train Accuracy = 0.408 Validation Accuracy = 0.579
#
# EPOCH 20 ...
# Loss = 1.896 Train Accuracy = 0.421 Validation Accuracy = 0.614
#
# EPOCH 21 ...
# Loss = 1.860 Train Accuracy = 0.432 Validation Accuracy = 0.642
#
# EPOCH 22 ...
# Loss = 1.806 Train Accuracy = 0.451 Validation Accuracy = 0.672
#
# EPOCH 23 ...
# Loss = 1.751 Train Accuracy = 0.466 Validation Accuracy = 0.656
#
# EPOCH 24 ...
# Loss = 1.727 Train Accuracy = 0.479 Validation Accuracy = 0.701
#
# EPOCH 25 ...
# Loss = 1.691 Train Accuracy = 0.487 Validation Accuracy = 0.713
#
# EPOCH 26 ...
# Loss = 1.657 Train Accuracy = 0.501 Validation Accuracy = 0.744
#
# EPOCH 27 ...
# Loss = 1.638 Train Accuracy = 0.508 Validation Accuracy = 0.755
#
# EPOCH 28 ...
# Loss = 1.596 Train Accuracy = 0.520 Validation Accuracy = 0.744
#
# EPOCH 29 ...
# Loss = 1.598 Train Accuracy = 0.522 Validation Accuracy = 0.779
#
# EPOCH 30 ...
# Loss = 1.593 Train Accuracy = 0.524 Validation Accuracy = 0.789
#
# EPOCH 31 ...
# Loss = 1.545 Train Accuracy = 0.535 Validation Accuracy = 0.809
#
# EPOCH 32 ...
# Loss = 1.546 Train Accuracy = 0.536 Validation Accuracy = 0.789
#
# EPOCH 33 ...
# Loss = 1.515 Train Accuracy = 0.547 Validation Accuracy = 0.814
#
# EPOCH 34 ...
# Loss = 1.507 Train Accuracy = 0.548 Validation Accuracy = 0.811
#
# EPOCH 35 ...
# Loss = 1.484 Train Accuracy = 0.558 Validation Accuracy = 0.833
#
# EPOCH 36 ...
# Loss = 1.474 Train Accuracy = 0.558 Validation Accuracy = 0.825
#
# EPOCH 37 ...
# Loss = 1.451 Train Accuracy = 0.568 Validation Accuracy = 0.837
#
# EPOCH 38 ...
# Loss = 1.465 Train Accuracy = 0.566 Validation Accuracy = 0.835
#
# EPOCH 39 ...
# Loss = 1.430 Train Accuracy = 0.577 Validation Accuracy = 0.848
#
# EPOCH 40 ...
# Loss = 1.429 Train Accuracy = 0.575 Validation Accuracy = 0.856
#
# EPOCH 41 ...
# Loss = 1.412 Train Accuracy = 0.580 Validation Accuracy = 0.842
#
# EPOCH 42 ...
# Loss = 1.398 Train Accuracy = 0.585 Validation Accuracy = 0.860
#
# EPOCH 43 ...
# Loss = 1.395 Train Accuracy = 0.584 Validation Accuracy = 0.861
#
# EPOCH 44 ...
# Loss = 1.391 Train Accuracy = 0.590 Validation Accuracy = 0.866
#
# EPOCH 45 ...
# Loss = 1.384 Train Accuracy = 0.593 Validation Accuracy = 0.865
#
# EPOCH 46 ...
# Loss = 1.360 Train Accuracy = 0.599 Validation Accuracy = 0.856
#
# EPOCH 47 ...
# Loss = 1.373 Train Accuracy = 0.600 Validation Accuracy = 0.865
#
# EPOCH 48 ...
# Loss = 1.347 Train Accuracy = 0.604 Validation Accuracy = 0.876
#
# EPOCH 49 ...
# Loss = 1.344 Train Accuracy = 0.603 Validation Accuracy = 0.878
#
# EPOCH 50 ...
# Loss = 1.341 Train Accuracy = 0.605 Validation Accuracy = 0.876
#
# EPOCH 51 ...
# Loss = 1.335 Train Accuracy = 0.608 Validation Accuracy = 0.884
#
# EPOCH 52 ...
# Loss = 1.315 Train Accuracy = 0.615 Validation Accuracy = 0.883
#
# EPOCH 53 ...
# Loss = 1.318 Train Accuracy = 0.612 Validation Accuracy = 0.891
#
# EPOCH 54 ...
# Loss = 1.305 Train Accuracy = 0.619 Validation Accuracy = 0.897
#
# EPOCH 55 ...
# Loss = 1.294 Train Accuracy = 0.625 Validation Accuracy = 0.903
#
# EPOCH 56 ...
# Loss = 1.308 Train Accuracy = 0.622 Validation Accuracy = 0.907
#
# EPOCH 57 ...
# Loss = 1.295 Train Accuracy = 0.623 Validation Accuracy = 0.901
#
# EPOCH 58 ...
# Loss = 1.290 Train Accuracy = 0.626 Validation Accuracy = 0.898
#
# EPOCH 59 ...
# Loss = 1.290 Train Accuracy = 0.624 Validation Accuracy = 0.903
#
# EPOCH 60 ...
# Loss = 1.265 Train Accuracy = 0.632 Validation Accuracy = 0.911
#
# EPOCH 61 ...
# Loss = 1.263 Train Accuracy = 0.636 Validation Accuracy = 0.909
#
# EPOCH 62 ...
# Loss = 1.266 Train Accuracy = 0.635 Validation Accuracy = 0.913
#
# EPOCH 63 ...
# Loss = 1.260 Train Accuracy = 0.637 Validation Accuracy = 0.905
#
# EPOCH 64 ...
# Loss = 1.243 Train Accuracy = 0.644 Validation Accuracy = 0.912
#
# EPOCH 65 ...
# Loss = 1.254 Train Accuracy = 0.639 Validation Accuracy = 0.917
#
# EPOCH 66 ...
# Loss = 1.248 Train Accuracy = 0.644 Validation Accuracy = 0.912
#
# EPOCH 67 ...
# Loss = 1.244 Train Accuracy = 0.644 Validation Accuracy = 0.910
#
# EPOCH 68 ...
# Loss = 1.243 Train Accuracy = 0.641 Validation Accuracy = 0.917
#
# EPOCH 69 ...
# Loss = 1.244 Train Accuracy = 0.642 Validation Accuracy = 0.919
#
# EPOCH 70 ...
# Loss = 1.241 Train Accuracy = 0.644 Validation Accuracy = 0.913
#
# EPOCH 71 ...
# Loss = 1.223 Train Accuracy = 0.649 Validation Accuracy = 0.917
#
# EPOCH 72 ...
# Loss = 1.211 Train Accuracy = 0.653 Validation Accuracy = 0.923
#
# EPOCH 73 ...
# Loss = 1.218 Train Accuracy = 0.654 Validation Accuracy = 0.914
#
# EPOCH 74 ...
# Loss = 1.209 Train Accuracy = 0.655 Validation Accuracy = 0.920
#
# EPOCH 75 ...
# Loss = 1.211 Train Accuracy = 0.654 Validation Accuracy = 0.923
#
# EPOCH 76 ...
# Loss = 1.213 Train Accuracy = 0.656 Validation Accuracy = 0.923
#
# EPOCH 77 ...
# Loss = 1.189 Train Accuracy = 0.661 Validation Accuracy = 0.926
#
# EPOCH 78 ...
# Loss = 1.210 Train Accuracy = 0.653 Validation Accuracy = 0.935
#
# EPOCH 79 ...
# Loss = 1.191 Train Accuracy = 0.661 Validation Accuracy = 0.912
#
# EPOCH 80 ...
# Loss = 1.203 Train Accuracy = 0.660 Validation Accuracy = 0.930
#
# EPOCH 81 ...
# Loss = 1.189 Train Accuracy = 0.666 Validation Accuracy = 0.929
#
# EPOCH 82 ...
# Loss = 1.168 Train Accuracy = 0.668 Validation Accuracy = 0.925
#
# EPOCH 83 ...
# Loss = 1.186 Train Accuracy = 0.665 Validation Accuracy = 0.921
#
# EPOCH 84 ...
# Loss = 1.184 Train Accuracy = 0.662 Validation Accuracy = 0.921
#
# EPOCH 85 ...
# Loss = 1.189 Train Accuracy = 0.662 Validation Accuracy = 0.934
#
# EPOCH 86 ...
# Loss = 1.177 Train Accuracy = 0.667 Validation Accuracy = 0.928
#
# EPOCH 87 ...
# Loss = 1.172 Train Accuracy = 0.672 Validation Accuracy = 0.935
#
# EPOCH 88 ...
# Loss = 1.167 Train Accuracy = 0.671 Validation Accuracy = 0.932
#
# EPOCH 89 ...
# Loss = 1.170 Train Accuracy = 0.672 Validation Accuracy = 0.934
#
# EPOCH 90 ...
# Loss = 1.161 Train Accuracy = 0.673 Validation Accuracy = 0.934
#
# EPOCH 91 ...
# Loss = 1.159 Train Accuracy = 0.671 Validation Accuracy = 0.943
#
# EPOCH 92 ...
# Loss = 1.163 Train Accuracy = 0.673 Validation Accuracy = 0.942
#
# EPOCH 93 ...
# Loss = 1.160 Train Accuracy = 0.675 Validation Accuracy = 0.941
#
# EPOCH 94 ...
# Loss = 1.151 Train Accuracy = 0.677 Validation Accuracy = 0.939
#
# EPOCH 95 ...
# Loss = 1.157 Train Accuracy = 0.676 Validation Accuracy = 0.936
#
# EPOCH 96 ...
# Loss = 1.140 Train Accuracy = 0.679 Validation Accuracy = 0.934
#
# EPOCH 97 ...
# Loss = 1.153 Train Accuracy = 0.677 Validation Accuracy = 0.924
#
# EPOCH 98 ...
# Loss = 1.143 Train Accuracy = 0.678 Validation Accuracy = 0.935
#
# EPOCH 99 ...
# Loss = 1.143 Train Accuracy = 0.680 Validation Accuracy = 0.939
#
# EPOCH 100 ...
# Loss = 1.145 Train Accuracy = 0.680 Validation Accuracy = 0.940
#
# EPOCH 101 ...
# Loss = 1.135 Train Accuracy = 0.680 Validation Accuracy = 0.937
#
# EPOCH 102 ...
# Loss = 1.144 Train Accuracy = 0.680 Validation Accuracy = 0.939
#
# EPOCH 103 ...
# Loss = 1.133 Train Accuracy = 0.679 Validation Accuracy = 0.940
#
# EPOCH 104 ...
# Loss = 1.128 Train Accuracy = 0.686 Validation Accuracy = 0.945
#
# EPOCH 105 ...
# Loss = 1.124 Train Accuracy = 0.686 Validation Accuracy = 0.934
# EPOCH 106 ...
# Loss = 1.129 Train Accuracy = 0.686 Validation Accuracy = 0.943
#
# EPOCH 107 ...
# Loss = 1.120 Train Accuracy = 0.687 Validation Accuracy = 0.939
#
# EPOCH 108 ...
# Loss = 1.132 Train Accuracy = 0.685 Validation Accuracy = 0.942
#
# EPOCH 109 ...
# Loss = 1.118 Train Accuracy = 0.687 Validation Accuracy = 0.946
#
# EPOCH 110 ...
# Loss = 1.108 Train Accuracy = 0.693 Validation Accuracy = 0.936
#
# EPOCH 111 ...
# Loss = 1.124 Train Accuracy = 0.685 Validation Accuracy = 0.944
#
# EPOCH 112 ...
# Loss = 1.115 Train Accuracy = 0.689 Validation Accuracy = 0.936
#
# EPOCH 113 ...
# Loss = 1.114 Train Accuracy = 0.692 Validation Accuracy = 0.939
#
# EPOCH 114 ...
# Loss = 1.111 Train Accuracy = 0.692 Validation Accuracy = 0.934
#
# EPOCH 115 ...
# Loss = 1.122 Train Accuracy = 0.688 Validation Accuracy = 0.946
#
# EPOCH 116 ...
# Loss = 1.103 Train Accuracy = 0.694 Validation Accuracy = 0.945
#
# EPOCH 117 ...
# Loss = 1.110 Train Accuracy = 0.692 Validation Accuracy = 0.934
#
# EPOCH 118 ...
# Loss = 1.109 Train Accuracy = 0.690 Validation Accuracy = 0.940
#
# EPOCH 119 ...
# Loss = 1.102 Train Accuracy = 0.694 Validation Accuracy = 0.925
#
# EPOCH 120 ...
# Loss = 1.099 Train Accuracy = 0.692 Validation Accuracy = 0.945
#
# EPOCH 121 ...
# Loss = 1.112 Train Accuracy = 0.690 Validation Accuracy = 0.944
#
# EPOCH 122 ...
# Loss = 1.108 Train Accuracy = 0.692 Validation Accuracy = 0.944
#
# EPOCH 123 ...
# Loss = 1.098 Train Accuracy = 0.696 Validation Accuracy = 0.946
#
# EPOCH 124 ...
# Loss = 1.085 Train Accuracy = 0.698 Validation Accuracy = 0.941
#
# EPOCH 125 ...
# Loss = 1.106 Train Accuracy = 0.694 Validation Accuracy = 0.944
#
# EPOCH 126 ...
# Loss = 1.099 Train Accuracy = 0.695 Validation Accuracy = 0.949
#
# EPOCH 127 ...
# Loss = 1.077 Train Accuracy = 0.700 Validation Accuracy = 0.946
#
# EPOCH 128 ...
# Loss = 1.097 Train Accuracy = 0.698 Validation Accuracy = 0.941
#
# EPOCH 129 ...
# Loss = 1.097 Train Accuracy = 0.697 Validation Accuracy = 0.947
#
# EPOCH 130 ...
# Loss = 1.078 Train Accuracy = 0.702 Validation Accuracy = 0.947
#
# EPOCH 131 ...
# Loss = 1.095 Train Accuracy = 0.695 Validation Accuracy = 0.942
#
# EPOCH 132 ...
# Loss = 1.090 Train Accuracy = 0.699 Validation Accuracy = 0.944
#
# EPOCH 133 ...
# Loss = 1.079 Train Accuracy = 0.702 Validation Accuracy = 0.947
#
# EPOCH 134 ...
# Loss = 1.090 Train Accuracy = 0.698 Validation Accuracy = 0.949
#
# EPOCH 135 ...
# Loss = 1.082 Train Accuracy = 0.704 Validation Accuracy = 0.941
#
# EPOCH 136 ...
# Loss = 1.101 Train Accuracy = 0.698 Validation Accuracy = 0.944
#
# EPOCH 137 ...
# Loss = 1.079 Train Accuracy = 0.703 Validation Accuracy = 0.952
#
# EPOCH 138 ...
# Loss = 1.090 Train Accuracy = 0.699 Validation Accuracy = 0.946
#
# EPOCH 139 ...
# Loss = 1.078 Train Accuracy = 0.704 Validation Accuracy = 0.943
#
# EPOCH 140 ...
# Loss = 1.078 Train Accuracy = 0.704 Validation Accuracy = 0.945
#
# EPOCH 141 ...
# Loss = 1.075 Train Accuracy = 0.704 Validation Accuracy = 0.943
#
# EPOCH 142 ...
# Loss = 1.072 Train Accuracy = 0.705 Validation Accuracy = 0.950
#
# EPOCH 143 ...
# Loss = 1.083 Train Accuracy = 0.702 Validation Accuracy = 0.946
#
# EPOCH 144 ...
# Loss = 1.081 Train Accuracy = 0.703 Validation Accuracy = 0.946
#
# EPOCH 145 ...
# Loss = 1.064 Train Accuracy = 0.706 Validation Accuracy = 0.950
#
# EPOCH 146 ...
# Loss = 1.073 Train Accuracy = 0.707 Validation Accuracy = 0.943
#
# EPOCH 147 ...
# Loss = 1.078 Train Accuracy = 0.701 Validation Accuracy = 0.949
#
# EPOCH 148 ...
# Loss = 1.070 Train Accuracy = 0.705 Validation Accuracy = 0.948
#
# EPOCH 149 ...
# Loss = 1.066 Train Accuracy = 0.706 Validation Accuracy = 0.952
#
# EPOCH 150 ...
# Loss = 1.068 Train Accuracy = 0.706 Validation Accuracy = 0.946
#
# EPOCH 151 ...
# Loss = 1.066 Train Accuracy = 0.708 Validation Accuracy = 0.948
#
# EPOCH 152 ...
# Loss = 1.065 Train Accuracy = 0.708 Validation Accuracy = 0.945
#
# EPOCH 153 ...
# Loss = 1.072 Train Accuracy = 0.705 Validation Accuracy = 0.944
#
# EPOCH 154 ...
# Loss = 1.065 Train Accuracy = 0.707 Validation Accuracy = 0.951
#
# EPOCH 155 ...
# Loss = 1.060 Train Accuracy = 0.711 Validation Accuracy = 0.949
#
# EPOCH 156 ...
# Loss = 1.069 Train Accuracy = 0.705 Validation Accuracy = 0.949
#
# EPOCH 157 ...
# Loss = 1.076 Train Accuracy = 0.701 Validation Accuracy = 0.947
#
# EPOCH 158 ...
# Loss = 1.068 Train Accuracy = 0.707 Validation Accuracy = 0.947
#
# EPOCH 159 ...
# Loss = 1.062 Train Accuracy = 0.711 Validation Accuracy = 0.948
#
# EPOCH 160 ...
# Loss = 1.056 Train Accuracy = 0.710 Validation Accuracy = 0.954
#
# EPOCH 161 ...
# Loss = 1.062 Train Accuracy = 0.708 Validation Accuracy = 0.946
#
# EPOCH 162 ...
# Loss = 1.064 Train Accuracy = 0.710 Validation Accuracy = 0.945
#
# EPOCH 163 ...
# Loss = 1.110 Train Accuracy = 0.700 Validation Accuracy = 0.950
#
# EPOCH 164 ...
# Loss = 1.055 Train Accuracy = 0.711 Validation Accuracy = 0.946
#
# EPOCH 165 ...
# Loss = 1.051 Train Accuracy = 0.713 Validation Accuracy = 0.949
#
# EPOCH 166 ...
# Loss = 1.057 Train Accuracy = 0.709 Validation Accuracy = 0.952
#
# EPOCH 167 ...
# Loss = 1.049 Train Accuracy = 0.713 Validation Accuracy = 0.954
#
# EPOCH 168 ...
# Loss = 1.050 Train Accuracy = 0.713 Validation Accuracy = 0.946
#
# EPOCH 169 ...
# Loss = 1.049 Train Accuracy = 0.712 Validation Accuracy = 0.948
#
# EPOCH 170 ...
# Loss = 1.054 Train Accuracy = 0.712 Validation Accuracy = 0.944
#
# EPOCH 171 ...
# Loss = 1.041 Train Accuracy = 0.716 Validation Accuracy = 0.948
#
# EPOCH 172 ...
# Loss = 1.050 Train Accuracy = 0.713 Validation Accuracy = 0.943
#
# EPOCH 173 ...
# Loss = 1.051 Train Accuracy = 0.711 Validation Accuracy = 0.951
#
# EPOCH 174 ...
# Loss = 1.046 Train Accuracy = 0.716 Validation Accuracy = 0.949
#
# EPOCH 175 ...
# Loss = 1.046 Train Accuracy = 0.713 Validation Accuracy = 0.949
#
# EPOCH 176 ...
# Loss = 1.054 Train Accuracy = 0.711 Validation Accuracy = 0.950
#
# EPOCH 177 ...
# Loss = 1.051 Train Accuracy = 0.711 Validation Accuracy = 0.950
#
# EPOCH 178 ...
# Loss = 1.044 Train Accuracy = 0.714 Validation Accuracy = 0.950
#
# EPOCH 179 ...
# Loss = 1.056 Train Accuracy = 0.712 Validation Accuracy = 0.953
#
# EPOCH 180 ...
# Loss = 1.051 Train Accuracy = 0.713 Validation Accuracy = 0.952
#
# EPOCH 181 ...
# Loss = 1.038 Train Accuracy = 0.718 Validation Accuracy = 0.950
#
# EPOCH 182 ...
# Loss = 1.051 Train Accuracy = 0.709 Validation Accuracy = 0.951
#
# EPOCH 183 ...
# Loss = 1.039 Train Accuracy = 0.714 Validation Accuracy = 0.956
#
# EPOCH 184 ...
# Loss = 1.046 Train Accuracy = 0.715 Validation Accuracy = 0.954
#
# EPOCH 185 ...
# Loss = 1.051 Train Accuracy = 0.713 Validation Accuracy = 0.947
#
# EPOCH 186 ...
# Loss = 1.040 Train Accuracy = 0.717 Validation Accuracy = 0.947
#
# EPOCH 187 ...
# Loss = 1.051 Train Accuracy = 0.717 Validation Accuracy = 0.957
#
# EPOCH 188 ...
# Loss = 1.040 Train Accuracy = 0.715 Validation Accuracy = 0.956
#
# EPOCH 189 ...
# Loss = 1.044 Train Accuracy = 0.713 Validation Accuracy = 0.952
#
# EPOCH 190 ...
# Loss = 1.035 Train Accuracy = 0.719 Validation Accuracy = 0.948
#
# EPOCH 191 ...
# Loss = 1.046 Train Accuracy = 0.714 Validation Accuracy = 0.951
#
# EPOCH 192 ...
# Loss = 1.031 Train Accuracy = 0.718 Validation Accuracy = 0.953
#
# EPOCH 193 ...
# Loss = 1.026 Train Accuracy = 0.722 Validation Accuracy = 0.954
#
# EPOCH 194 ...
# Loss = 1.030 Train Accuracy = 0.719 Validation Accuracy = 0.950
#
# EPOCH 195 ...
# Loss = 1.034 Train Accuracy = 0.717 Validation Accuracy = 0.950
#
# EPOCH 196 ...
# Loss = 1.031 Train Accuracy = 0.716 Validation Accuracy = 0.952
#
# EPOCH 197 ...
# Loss = 1.048 Train Accuracy = 0.715 Validation Accuracy = 0.951
#
# EPOCH 198 ...
# Loss = 1.044 Train Accuracy = 0.717 Validation Accuracy = 0.958
#
# EPOCH 199 ...
# Loss = 1.041 Train Accuracy = 0.716 Validation Accuracy = 0.954
#
# EPOCH 200 ...
# Loss = 1.037 Train Accuracy = 0.714 Validation Accuracy = 0.954
#
# Model saved

# %%
#Final test on hold-out test set

with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))

    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet
# Test Accuracy = 0.716

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
